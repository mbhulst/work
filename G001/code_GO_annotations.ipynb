# %% [markdown]
# # GO annotation

# %%
import my_functions as fun
import pandas as pd

# %% [markdown]
# # Import annotation files

# %%
# headers obtained from: https://interproscan-docs.readthedocs.io/en/latest/UserDocs.html#output-formats
headers = ['Protein accession',
           'Sequence MD5 digest', 
           'Sequence length', 
           'Analysis', 
           'Signature accession', 
           'Signature description', 
           'Start location', 
           'Stop location', 
           'Score', 
           'True', 
           'Date',
           'InterPro annotations - accession', 
           'InterPro annotations - description', 
           'GO annotations',
           'to be removed']

# %%
# open the InterProScan .tsv file and read into a dataframe
df_WT_ips = pd.read_csv(fun.get_file_path('NZ_CP022438_S.peucetius_subsp.caesius_ATCC_27952_chromosome_proteins.ipscan.tsv'), sep="\t", header=None)
df_WT_ips.columns = headers
df_WT_ips = df_WT_ips.drop(labels='to be removed', axis=1)  # remove last column that does not contain data

# %%
df_WT_ips_ed = df_WT_ips[df_WT_ips["GO annotations"].notna()]

# %%
df_WT_ips_ed[df_WT_ips_ed["GO annotations"].str.contains("GO:0003700")]
# Out:
#       Protein accession               Sequence MD5 digest  Sequence length  \
# 252       CGZ69_RS29270  9ac09c4ac235a9a81be8abc318e55ca0              154
# 253       CGZ69_RS29270  9ac09c4ac235a9a81be8abc318e55ca0              154
# 256       CGZ69_RS29270  9ac09c4ac235a9a81be8abc318e55ca0              154
# 535       CGZ69_RS14030  994b7143fc836024ac873b0459ff0c05              301
# 536       CGZ69_RS14030  994b7143fc836024ac873b0459ff0c05              301
# ...                 ...                               ...              ...
# 46974     CGZ69_RS27660  83c92fb6a4d7164e2eaad5b2c47a298c              225
# 46975     CGZ69_RS27660  83c92fb6a4d7164e2eaad5b2c47a298c              225
# 47049     CGZ69_RS22120  7976bcef5a167557cb31fd48ec153a4b              123
# 47050     CGZ69_RS22120  7976bcef5a167557cb31fd48ec153a4b              123
# 47055     CGZ69_RS22120  7976bcef5a167557cb31fd48ec153a4b              123
#
#               Analysis Signature accession  \
# 252    ProSiteProfiles             PS50995
# 253               Pfam             PF01047
# 256              SMART             SM00347
# 535               Pfam             PF04542
# 536             PRINTS             PR00046
# ...                ...                 ...
# 46974           PRINTS             PR00035
# 46975  ProSiteProfiles             PS50949
# 47049  ProSiteProfiles             PS50995
# 47050            SMART             SM00347
# 47055             Pfam             PF01047
#
#                                  Signature description  Start location  \
# 252                      MarR-type HTH domain profile.              18
# 253                                        MarR family              45
# 256                                          marrlong4              38
# 535                                  Sigma-70 region 2              80
# 536                    Major sigma-70 factor signature             104
# ...                                                ...             ...
# 46974  GntR bacterial regulatory protein HTH signature              40
# 46975                    GntR-type HTH domain profile.               2
# 47049                    MarR-type HTH domain profile.               1
# 47050                                        marrlong4               1
# 47055                                      MarR family              16
#
#        Stop location    Score True        Date  \
# 252              148   25.348    T  07-11-2020
# 253              103  1.3E-16    T  07-11-2020
# 256              136  7.3E-23    T  07-11-2020
# 535              149  1.5E-15    T  07-11-2020
# 536              117  7.0E-12    T  07-11-2020
# ...              ...      ...  ...         ...
# 46974             56   1.1E-7    T  07-11-2020
# 46975             69   19.588    T  07-11-2020
# 47049            102   20.424    T  07-11-2020
# 47050             90   7.0E-6    T  07-11-2020
# 47055             55  5.6E-12    T  07-11-2020
#
#       InterPro annotations - accession InterPro annotations - description  \
# 252                          IPR000835               MarR-type HTH domain
# 253                          IPR000835               MarR-type HTH domain
# 256                          IPR000835               MarR-type HTH domain
# 535                          IPR007627   RNA polymerase sigma-70 region 2
# 536                          IPR000943            RNA polymerase sigma-70
# ...                                ...                                ...
# 46974                        IPR000524  Transcription regulator HTH, GntR
# 46975                        IPR000524  Transcription regulator HTH, GntR
# 47049                        IPR000835               MarR-type HTH domain
# 47050                        IPR000835               MarR-type HTH domain
# 47055                        IPR000835               MarR-type HTH domain
#
#                          GO annotations
# 252               GO:0003700|GO:0006355
# 253               GO:0003700|GO:0006355
# 256               GO:0003700|GO:0006355
# 535    GO:0003700|GO:0006352|GO:0006355
# 536    GO:0003700|GO:0006352|GO:0006355
# ...                                 ...
# 46974             GO:0003700|GO:0006355
# 46975             GO:0003700|GO:0006355
# 47049             GO:0003700|GO:0006355
# 47050             GO:0003700|GO:0006355
# 47055             GO:0003700|GO:0006355
#
# [858 rows x 14 columns]

# %%
# open the Panther .tsv file and read into a dataframe
df_WT_pthr = pd.read_csv(fun.get_file_path('NZ_CP022438_S.peucetius_subsp.caesius_ATCC_27952_chromosome_proteins.panther15.0.out.tsv'), sep="\t", header=None)
df_WT_pthr.columns = ["gene_code", "PANTHER_accession", "PANTHER_family", "HMM_Evalue-score", "HMM_bitscore", "alignment_range"]

# %%
df_WT_pthr.head()
# Out:
#        gene_code PANTHER_accession  \
# 0  CGZ69_RS17810         PTHR43335
# 1  CGZ69_RS27660    PTHR43537:SF34
# 2  CGZ69_RS25500         PTHR42891
# 3  CGZ69_RS19730     PTHR35007:SF4
# 4  CGZ69_RS15885         PTHR42964
#
#                                       PANTHER_family  HMM_Evalue-score  \
# 0               ABC TRANSPORTER, ATP-BINDING PROTEIN      3.600000e-79
# 1           PYRUVATE DEHYDROGENASE COMPLEX REPRESSOR      2.700000e-41
# 2  D-GLYCERO-BETA-D-MANNO-HEPTOSE-1,7-BISPHOSPHAT...      4.000000e-40
# 3                  INTEGRAL MEMBRANE PROTEIN-RELATED      4.300000e-57
# 4                                ENOYL-COA HYDRATASE      1.100000e-77
#
#    HMM_bitscore alignment_range
# 0         264.9           1-311
# 1         140.4           6-201
# 2         135.9           6-195
# 3         192.1          10-282
# 4         259.5           3-242

# %%
# How many genes have been annotated?
number = len(df_WT_pthr["gene_code"].unique())
("Panther codes identified for {} genes ({:.2g} % of all genes)").format(number, number/7129*100)
# Out:
# 'Panther codes identified for 4932 genes (69 % of all genes)'

# %%
# Initialize the output dataframe for panther analysis
pthr_input = df_WT_pthr[["gene_code", "PANTHER_accession"]]
pthr_input = pthr_input.sort_values("gene_code")

# %%
# Initialize the output dataframe for panther analysis
pthr_input = df_WT_pthr.sort_values("gene_code")

# %% [markdown]
# ## Import genbank file

# %%
import my_functions as fun
from Bio.Seq import Seq
from Bio import SeqIO

# %%
record = SeqIO.read(fun.get_file_path('sequence_NZ_CP0224381.gb'), "genbank")

# %%
# check the first few of features
gene_codes_NCBI = []

for i in range(len(record.features)):
    feat = record.features[i]
    if feat.type == "CDS":
        if "protein_id" in feat.qualifiers:
            gene_codes_NCBI.append(feat.qualifiers["locus_tag"][0])

# %%
len(gene_codes_NCBI)
# Out:
# 6403

# %%
# Add genes that do not have a panther term to the pthr_input file
for gene_code in gene_codes_NCBI:
    if gene_code not in list(pthr_input["gene_code"]):
        pthr_input = pthr_input.append(pd.DataFrame({"gene_code": [gene_code], "PANTHER_accession": ["unclassified"]}))

# %%
# Initialize the output dataframe for panther analysis
pthr_input = pthr_input.sort_values("gene_code")

# %%
pthr_input
# Out:
#           gene_code PANTHER_accession  \
# 0     CGZ69_RS00005      unclassified
# 3619  CGZ69_RS00010     PTHR43046:SF9
# 0     CGZ69_RS00015      unclassified
# 0     CGZ69_RS00020      unclassified
# 0     CGZ69_RS00035      unclassified
# ...             ...               ...
# 3878  CGZ69_RS37030         PTHR35004
# 4578  CGZ69_RS37035         PTHR44103
# 0     CGZ69_RS37040      unclassified
# 4820  CGZ69_RS37045    PTHR12714:SF19
# 0     CGZ69_RS37050      unclassified
#
#                                        PANTHER_family  HMM_Evalue-score  \
# 0                                                 NaN               NaN
# 3619          ADP-RIBOSE PYROPHOSPHATASE YJHB-RELATED      3.900000e-33
# 0                                                 NaN               NaN
# 0                                                 NaN               NaN
# 0                                                 NaN               NaN
# ...                                               ...               ...
# 3878                      TRANSPOSASE RV3428C-RELATED      1.300000e-07
# 4578                          PROPROTEIN CONVERTASE P      9.300000e-24
# 0                                                 NaN               NaN
# 4820  PROTEIN-S-ISOPRENYLCYSTEINE O-METHYLTRANSFERASE      1.500000e-05
# 0                                                 NaN               NaN
#
#       HMM_bitscore alignment_range
# 0              NaN             NaN
# 3619         112.9          21-143
# 0              NaN             NaN
# 0              NaN             NaN
# 0              NaN             NaN
# ...            ...             ...
# 3878          29.3          36-132
# 4578          82.1         366-595
# 0              NaN             NaN
# 4820          23.3            7-48
# 0              NaN             NaN
#
# [6411 rows x 6 columns]

# %% [markdown]
# # Select interesting genes

# %% [markdown]
# We can either use the file with all genes. However, we cannot filter out the mutations that occured further away than the promoter region. Therefore, we will use the annotated file. However, this means that the mutations are not ordered by gene.

# %%
# Import files from cwd
df_genes = pd.read_csv("df_genes.csv", delimiter=";", index_col=False, low_memory=False)
df_ann = pd.read_csv("df_ann.csv", delimiter=";", index_col=False, low_memory=False)

# %%
def panther_count(list_genes: list):
    """This function analyses the panther terms of the list of genes provided."""
    
    counter = 0

    for gene_code in list_genes:
        
        if gene_code in list(df_WT_pthr["gene_code"]):
            counter += 0    
        
        else:
            counter += 1
    
    print("The number of genes:", len(list_genes))
    print("The number of genes that have a panther code:", len(list_genes) - counter)
    print("The number of genes that do not have a panther code:", counter)

# %%
# Total genes affected by a mutation
list_total = list(df_genes["TranscriptId"])

print("Number of genes selected: {}".format(len(df_genes)))
print(f"Number of genes selected: {len(df_genes)}")
# Out:
# Number of genes selected: 5625
# Number of genes selected: 5625

# %%
# How many genes have a panther code of all genes that are affected by a mutation?
panther_count(list_total)
# Out:
# The number of genes: 5625
# The number of genes that have a panther code: 3950
# The number of genes that do not have a panther code: 1675

# %%
# All interesting mutations (high, moderate impact or within putative promoter regions)
df_ann_interesting = df_ann[(df_ann["Annotation_Impact"] == "HIGH") | 
                            (df_ann["Annotation_Impact"] == "MODERATE") | 
                            ((df_ann["Annotation_Impact"] == "MODIFIER") & (df_ann["Distance"] < 300))]

list_interesting = list(df_ann_interesting["Gene_ID"].unique())

print("Number of mutations selected: {}".format(len(df_ann_interesting)))
print("Number of genes selected: {}".format(len(list_interesting)))
# Out:
# Number of mutations selected: 1279
# Number of genes selected: 867

# %%
505/867
# Out:
# 0.5824682814302191

# %%
# How many genes have a panther code of all genes are selected as interesting?
panther_count(list_interesting)
# Out:
# The number of genes: 867
# The number of genes that have a panther code: 505
# The number of genes that do not have a panther code: 362

# %%
pthr_input
# Out:
#           gene_code PANTHER_accession  \
# 0     CGZ69_RS00005      unclassified
# 3619  CGZ69_RS00010     PTHR43046:SF9
# 0     CGZ69_RS00015      unclassified
# 0     CGZ69_RS00020      unclassified
# 0     CGZ69_RS00035      unclassified
# ...             ...               ...
# 3878  CGZ69_RS37030         PTHR35004
# 4578  CGZ69_RS37035         PTHR44103
# 0     CGZ69_RS37040      unclassified
# 4820  CGZ69_RS37045    PTHR12714:SF19
# 0     CGZ69_RS37050      unclassified
#
#                                        PANTHER_family  HMM_Evalue-score  \
# 0                                                 NaN               NaN
# 3619          ADP-RIBOSE PYROPHOSPHATASE YJHB-RELATED      3.900000e-33
# 0                                                 NaN               NaN
# 0                                                 NaN               NaN
# 0                                                 NaN               NaN
# ...                                               ...               ...
# 3878                      TRANSPOSASE RV3428C-RELATED      1.300000e-07
# 4578                          PROPROTEIN CONVERTASE P      9.300000e-24
# 0                                                 NaN               NaN
# 4820  PROTEIN-S-ISOPRENYLCYSTEINE O-METHYLTRANSFERASE      1.500000e-05
# 0                                                 NaN               NaN
#
#       HMM_bitscore alignment_range
# 0              NaN             NaN
# 3619         112.9          21-143
# 0              NaN             NaN
# 0              NaN             NaN
# 0              NaN             NaN
# ...            ...             ...
# 3878          29.3          36-132
# 4578          82.1         366-595
# 0              NaN             NaN
# 4820          23.3            7-48
# 0              NaN             NaN
#
# [6411 rows x 6 columns]

# %% [markdown]
# ## Create input for panther analysis

# %%
# Remove duplicates with multiple accession codes from dataframe:
# Note this is absolutely not robust and really needs to be redone!!!!
df_duplicates = pthr_input[pthr_input['gene_code'].duplicated(keep=False)]
idx_duplicates = pthr_input[pthr_input['gene_code'].duplicated(keep=False)].index.values.tolist()

pthr_input = pthr_input.drop(idx_duplicates[::2]) # remove every other row.... NEEDS TO BE REDONE

# %%
def panther_input(list_genes):
    """This function returns a dictionary of the panther terms of the list of genes provided."""
    
    counter = 0
    dict_genes = {gene_code: 0 for gene_code in pthr_input["gene_code"]}

    for gene_code in list_genes:
        
        if gene_code in dict_genes:
            dict_genes[gene_code] = 1
        
        else:

            counter += 1
            
    return dict_genes

# %%
# Find the panther terms of each gene in the list and add to the pthr input dataframe
pthr_input_quan = panther_input(list_interesting)

# %%
pthr_input.to_csv("pthr_input_ref.txt", index=False, sep = '\t', header="none")

# %%
pthr_input["quantification"] = pthr_input["gene_code"].apply(lambda x: pthr_input_quan[x])
# Out:
# <ipython-input-28-3e49f8733f0a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pthr_input["quantification"] = pthr_input["gene_code"].apply(lambda x: pthr_input_quan[x])

# %%
pthr_input_ana = pthr_input[pthr_input["quantification"] == 1]

# %%
pthr_input_ana.to_csv("pthr_input_ana.txt", index=False, sep = '\t', header="none")

# %%
len(pthr_input["gene_code"].unique())
# Out:
# 6403

# %%
len(pthr_input_ana["gene_code"].unique())
# Out:
# 600

# %%
pthr_input
# Out:
#           gene_code PANTHER_accession  \
# 0     CGZ69_RS00005      unclassified
# 3619  CGZ69_RS00010     PTHR43046:SF9
# 0     CGZ69_RS00015      unclassified
# 0     CGZ69_RS00020      unclassified
# 0     CGZ69_RS00035      unclassified
# ...             ...               ...
# 3878  CGZ69_RS37030         PTHR35004
# 4578  CGZ69_RS37035         PTHR44103
# 0     CGZ69_RS37040      unclassified
# 4820  CGZ69_RS37045    PTHR12714:SF19
# 0     CGZ69_RS37050      unclassified
#
#                                        PANTHER_family  HMM_Evalue-score  \
# 0                                                 NaN               NaN
# 3619          ADP-RIBOSE PYROPHOSPHATASE YJHB-RELATED      3.900000e-33
# 0                                                 NaN               NaN
# 0                                                 NaN               NaN
# 0                                                 NaN               NaN
# ...                                               ...               ...
# 3878                      TRANSPOSASE RV3428C-RELATED      1.300000e-07
# 4578                          PROPROTEIN CONVERTASE P      9.300000e-24
# 0                                                 NaN               NaN
# 4820  PROTEIN-S-ISOPRENYLCYSTEINE O-METHYLTRANSFERASE      1.500000e-05
# 0                                                 NaN               NaN
#
#       HMM_bitscore alignment_range  quantification
# 0              NaN             NaN               0
# 3619         112.9          21-143               0
# 0              NaN             NaN               0
# 0              NaN             NaN               0
# 0              NaN             NaN               0
# ...            ...             ...             ...
# 3878          29.3          36-132               0
# 4578          82.1         366-595               0
# 0              NaN             NaN               0
# 4820          23.3            7-48               0
# 0              NaN             NaN               0
#
# [6403 rows x 7 columns]

# %%
families = list(pthr_input["PANTHER_family"].unique())

for family in families:
    if type(family) is str:
        if "BINDING" in family:
            print(family)
# Out:
# HIGH-AFFINITY BRANCHED-CHAIN AMINO ACID TRANSPORT ATP-BINDING PROTEIN LIVF
# BRANCHED-CHAIN AMINO ACID TRANSPORT ATP-BINDING PROTEIN-RELATED
# PENICILLIN-BINDING PROTEIN 1A
# ARABINOSE-BINDING PROTEIN-RELATED
# DNA-BINDING PROTEIN
# IRON(3+)-HYDROXAMATE IMPORT ATP-BINDING PROTEIN FHUC
# PEBP (PHOSPHATIDYLETHANOLAMINE-BINDING PROTEIN) FAMILY PROTEIN
# FAD-BINDING, PUTATIVE (AFU_ORTHOLOGUE AFUA_6G07600)-RELATED
# ABC-TRANSPORT SYSTEM ATP BINDING PROTEIN-RELATED
# D-ALLOSE-BINDING PERIPLASMIC PROTEIN-RELATED
# POSSIBLE DNA-BINDING PROTEIN
# TREHALOSE IMPORT ATP-BINDING PROTEIN SUGC
# ABC TRANSPORTER ATP-BINDING PROTEIN SCO5958-RELATED
# ALDEHYDE OXIDOREDUCTASE IRON-SULFUR-BINDING SUBUNIT PAOA
# ATP-BINDING CASSETTE SUB-FAMILY B MEMBER 7, MITOCHONDRIAL
# ABC TRANSPORTER GLUTAMINE-BINDING PROTEIN GLNH
# ATP/GTP-BINDING PROTEIN-RELATED
# NAD(P)-BINDING PROTEIN YBJT-RELATED
# FE(3+) DICITRATE TRANSPORT ATP-BINDING PROTEIN FECE-RELATED
# MULTIDRUG RESISTANCE-LIKE ATP-BINDING PROTEIN MDLB
# FAD/NAD(P)-BINDING OXIDOREDUCTASE FAMILY PROTEIN
# PERIPLASMIC OLIGOPEPTIDE-BINDING PROTEIN-RELATED
# DNA-BINDING PROTEIN YWZG-RELATED
# DNA-BINDING REGULATOR-RELATED
# METHIONINE-BINDING LIPOPROTEIN METQ
# METHIONINE IMPORT ATP-BINDING PROTEIN METN
# PERIPLASMIC BINDING PROTEIN
# 39 KDA FK506-BINDING NUCLEAR PROTEIN
# PERIPLASMIC BINDING COMPONENT OF ABC TRANSPORTER
# GLCNAC-BINDING PROTEIN A
# GTP-BINDING PROTEIN
# ABC TRANSPORTER ATP-BINDING PROTEIN MODF
# ABC TRANSPORTER ATP BINDING PROTEIN-RELATED
# CAMP-BINDING PROTEIN 1-RELATED
# NOD FACTOR EXPORT ATP-BINDING PROTEIN I
# IRON-SULFUR-BINDING OXIDOREDUCTASE FADF-RELATED
# HIGH-AFFINITY BRANCHED-CHAIN AMINO ACID TRANSPORT ATP-BINDING PROTEIN LIVG
# LEU/ILE/VAL-BINDING ABC TRANSPORTER SUBUNIT
# ABC TRANSPORTER ATP-BINDING PROTEIN
# RNA POLYMERASE-BINDING TRANSCRIPTION FACTOR DKSA
# ATP-BINDING CASSETTE SUB-FAMILY G MEMBER 5
# PYRIDOXAMINE 5'-PHOSPHATE OXIDASE-RELATED FMN-BINDING
# ATP-BINDING PROTEIN RV3427C IN INSERTION SEQUENCE-RELATED
# IRON III  DICITRATE-BINDING PERIPLASMIC PROTEIN
# METALLOPHOSPHATASE BINDING DOMAIN PROTEIN
# CYCLIN-D-BINDING MYB-LIKE TRANSCRIPTION FACTOR 1
# INTERMEMBRANE PHOSPHOLIPID TRANSPORT SYSTEM BINDING PROTEIN MLAD-RELATED
# ABC TRANSPORTER ATP-BINDING PROTEIN MG014-RELATED
# ABC TRANSPORTER, ATP-BINDING/PERMEASE PROTEIN
# METAL TRANSPORT SYSTEM ATP-BINDING PROTEIN TM_0124-RELATED
# ATP-DEPENDENT CLP PROTEASE ATP-BINDING SUBUNIT CLPX-LIKE, MITOCHONDRIAL
# BINDING OXIDOREDUCTASE, PUTATIVE (AFU_ORTHOLOGUE AFUA_1G17690)-RELATED
# IMPORT ATP-BINDING PROTEIN
# SINGLE-STRANDED DNA-BINDING PROTEIN, MITOCHONDRIAL
# ABC TRANSPORTER, ATP-BINDING PROTEIN
# FE(3+) DICITRATE-BINDING PERIPLASMIC PROTEIN
# ABC TRANSPORTER ARGININE-BINDING PROTEIN ARTJ-RELATED
# L-CYSTINE TRANSPORT SYSTEM ATP-BINDING PROTEIN YECC
# D-XYLOSE-BINDING PERIPLASMIC PROTEIN
# ABC-TRANSPORT PROTEIN, ATP-BINDING COMPONENT-RELATED
# XANTHINE DEHYDROGENASE IRON-SULFUR-BINDING SUBUNIT XDHC-RELATED
# MALTOSE-BINDING PERIPLASMIC PROTEIN
# DNA-BINDING PROTEIN HU-BETA
# TMRNA-BINDING COMPONENT OF TRANS-TRANSLATION TAGGING COMPLEX
# CELL DIVISION ATP-BINDING PROTEIN FTSE
# BINDING PROTEIN MSME-RELATED
# TEICHOIC ACIDS EXPORT ATP-BINDING PROTEIN TAGH
# NICKEL IMPORT SYSTEM ATP-BINDING PROTEIN NIKE
# POTASSIUM BINDING PROTEIN KBP
# RIBOSOMAL PROTEIN L25/GLN-TRNA SYNTHETASE, ANTI-CODON-BINDING DOMAIN-CONTAINING PROTEIN
# ABC TRANSPORTER ATP-BINDING SUBUNIT
# CELL WALL-BINDING PROTEIN YOCH
# DNA-BINDING PROTEIN-RELATED
# LEUCINE-SPECIFIC-BINDING PROTEIN
# DOXORUBICIN RESISTANCE ATP-BINDING PROTEIN DRRA
# MALTODEXTRIN IMPORT ATP-BINDING PROTEIN MSMX
# FE(3+) IONS IMPORT ATP-BINDING PROTEIN FBPC
# PHOSPHATE-BINDING PROTEIN PSTS
# PHOSPHATE IMPORT ATP-BINDING PROTEIN PSTB 3
# DRUG RESISTANCE ABC TRANSPORTER,ATP-BINDING PROTEIN-RELATED
# ATP-BINDING/PERMEASE PROTEIN CYDD
# MULTIDRUG RESISTANCE ABC TRANSPORTER ATP-BINDING/PERMEASE PROTEIN BMRA
# BINDING PROTEIN TRANSPEPTIDASE, PUTATIVE-RELATED
# OSMOPROTECTANT IMPORT ATP-BINDING PROTEIN OSMV
# ATP-BINDING CASSETTE, SUB-FAMILY H, MEMBER 1
# GLYCINE BETAINE/PROLINE BETAINE TRANSPORT SYSTEM ATP-BINDING PROTEIN PROV
# CARBOHYDRATE TRANSPORT ATP-BINDING PROTEIN MG119-RELATED
# GLUTATHIONE IMPORT ATP-BINDING PROTEIN GSIA
# DIPEPTIDE TRANSPORT ATP-BINDING PROTEIN DPPD
# D,D-DIPEPTIDE-BINDING PERIPLASMIC PROTEIN DDPA-RELATED
# PEPTIDE TRANSPORT SYSTEM SECRETED PEPTIDE-BINDING PROTEIN-RELATED
# TRANSPORT ATP-BINDING PROTEIN
# OLIGOPEPTIDE TRANSPORT ATP-BINDING PROTEIN APPD
# AMINO ACID ABC TRANSPORTER ATP-BINDING PROTEIN
# HEMIN IMPORT ATP-BINDING PROTEIN HMUV
# IRON ABC TRANSPORTER, SUBSTRATE-BINDING PROTEIN-RELATED
# DNA-BINDING TRANSCRIPTIONAL ACTIVATOR ALPA
# ABC TRANSPORTER, ATP-BINDING SUBUNIT-RELATED
# CALCIUM-BINDING PROTEIN CML16-RELATED
# NAD(P)-BINDING ROSSMANN-FOLD SUPERFAMILY PROTEIN
# THIAMINE-BINDING PERIPLASMIC PROTEIN
# LIPOPROTEIN-RELEASING SYSTEM ATP-BINDING PROTEIN LOLD
# SPERMIDINE/PUTRESCINE IMPORT ATP-BINDING PROTEIN POTA
# RIBOSOME-BINDING FACTOR A, CHLOROPLASTIC-RELATED
# OPPC IN A BINDING PROTEIN-DEPENDENT TRANSPORT SYSTEM
# GLUTAMATE/ASPARTATE IMPORT ATP-BINDING PROTEIN GLTL
# GTP-BINDING PROTEIN 6-RELATED
# IRON(III) TRANSPORT SYSTEM, ATP-BINDING PROTEIN-RELATED
# IRON(III) DICITRATE-BINDING PROTEIN-RELATED
# PEPTIDOGLYCAN-BINDING PROTEIN
# TAURINE IMPORT ATP-BINDING PROTEIN-RELATED
# INTEGRAL MEMBRANE COMPONENTS OF OTHER BINDING-PROTEIN-DEPENDENT TRANSPORT SYSTEM
# ABC TRANSPORTER SUBSTRATE-BINDING PROTEIN
# ALIPHATIC SULFONATES-BINDING PROTEIN-RELATED
# LIPOPROTEIN-RELEASING SYSTEM ATP-BINDING PROTEIN LOLD 2
# ABC TRANSPORTER-BINDING PROTEIN DR_1438-RELATED
# SOLUTE-BINDING PROTEIN
# MOLYBDENUM IMPORT ATP-BINDING PROTEIN MODC
# MOLYBDATE-BINDING PROTEIN MODA
# INTERMEMBRANE PHOSPHOLIPID TRANSPORT SYSTEM BINDING PROTEIN MLAD
# INTERMEMBRANE PHOSPHOLIPID TRANSPORT SYSTEM ATP-BINDING PROTEIN MLAF
# BINDING ROSSMANN FOLD OXIDOREDUCTASE, PUTATIVE (AFU_ORTHOLOGUE AFUA_2G10240)-RELATED
# ABC TRANSPORTER PERIPLASMIC-BINDING PROTEIN YPHF
# RIBOSE IMPORT ATP-BINDING PROTEIN RBSA 2
# ABC TRANSPORTER ATP-BINDING PROTEIN-RELATED
# S1 RNA-BINDING DOMAIN-CONTAINING PROTEIN 1
# 4FE-4S FERREDOXIN IRON-SULFUR BINDING DOMAIN PROTEIN
# AMP-BINDING ENZYME
# MONOOXYGENASE, FAD-BINDING
# SUGAR ABC TRANSPORTER ATP-BINDING PROTEIN
# LIPID-BINDING PROTEIN
# ABC TRANSPORTER AMINO ACID-BINDING PROTEIN
# NICKEL IMPORT ATP-BINDING PROTEIN NIKD
# CARBOHYDRATE-BINDING PROTEIN-RELATED

# %%
type("hoi")
# Out:
# str
