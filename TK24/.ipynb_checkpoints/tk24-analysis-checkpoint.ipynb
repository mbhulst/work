# %% [markdown]
# # TK24 gDNA sequencing analysis

# %% [markdown]
# Location types:
# - variant
# - exonic variant (located in gene)
#
# Mutation types:
# - SNP (single nucleotide polymorphism)
# - InDel (insertion or deletion of < 50 bp of DNA)
# - SV (structural variants of > 50 bp of DNA)
# - CNV (copy number variation)

# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [55], in <module>
#       3 import pandas as pd
#       4 import numpy as np
# ----> 5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# get the file path of the file in the input folder to open them as a dataframe
def get_file_path(file_name: str):
        
    cwd = os.getcwd()
    file_path = cwd + '\\input\\' + file_name

    return file_path

# %%
# select all files belonging to the mutant
data_mut = []
for filename in os.listdir('./input'):
    if 'mut' in filename:
        data_mut.append(filename)

# select all files belonging to the wild type
data_wt = []
for filename in os.listdir('./input'):
    if 'wt' in filename:
        data_wt.append(filename)

# %%
num = 5

# %%
print(data_mut[num])
df_mut = pd.read_csv(get_file_path(data_mut[num]), sep='\t')
# Out:
# mut.sv.avinput.variant_function

# %%
print(data_wt[num])
df_wt = pd.read_csv(get_file_path(data_wt[num]), sep='\t')
# Out:
# wt.sv.avinput.variant_function

# %%
df_mut
# Out:
#    #LINE_ID ANNO_REGION                       ANNOTATION       CHROM     POS1  \
# 0     line1      exonic                  gene-SLIV_00465  CP009124.1    92704
# 1     line2      exonic  gene-SLIV_00845,gene-SLIV_00850  CP009124.1   165960
# 2     line3      exonic  gene-SLIV_01525,gene-SLIV_01530  CP009124.1   317852
# 3     line4      exonic                  gene-SLIV_01805  CP009124.1   383979
# 4     line5      exonic                  gene-SLIV_03395  CP009124.1   719520
# ..      ...         ...                              ...         ...      ...
# 80   line81      exonic                  gene-SLIV_34330  CP009124.1  7606894
# 81   line82      exonic  gene-SLIV_34920,gene-SLIV_34925  CP009124.1  7727025
# 82   line83      exonic                  gene-SLIV_35965  CP009124.1  7954969
# 83   line84      exonic                  gene-SLIV_36250  CP009124.1  8032372
# 84   line85      exonic                  gene-SLIV_37085  CP009124.1  8218742
#
#        POS2  REF ALT TYPE of SV            SIZE of SV
# 0     92988    0   -   Deletion  DEL:a 270bp deletion
# 1    166239    0   -   Deletion  DEL:a 279bp deletion
# 2    318130    0   -   Deletion  DEL:a 278bp deletion
# 3    384257    0   -   Deletion  DEL:a 276bp deletion
# 4    719826    0   -   Deletion  DEL:a 294bp deletion
# ..      ...  ...  ..        ...                   ...
# 80  7607159    0   -   Deletion  DEL:a 268bp deletion
# 81  7727337    0   -   Deletion  DEL:a 320bp deletion
# 82  7955264    0   -   Deletion  DEL:a 290bp deletion
# 83  8032758    0   -   Deletion  DEL:a 392bp deletion
# 84  8219023    0   -   Deletion  DEL:a 287bp deletion
#
# [85 rows x 10 columns]

# %%
df_wt
# Out:
# Empty DataFrame
# Columns: [#LINE_ID, ANNO_REGION, ANNOTATION, CHROM, POS1, POS2, REF, ALT, TYPE of SV, SIZE of SV]
# Index: []

# %%
cond = df_mut['ANNOTATION'].isin(df_wt['ANNOTATION'])
df_mut.drop(df_mut[cond].index, inplace = True)

# %%
df_mut
# Out:
#    #LINE_ID ANNO_REGION                       ANNOTATION       CHROM     POS1  \
# 0     line1      exonic                  gene-SLIV_00465  CP009124.1    92704
# 1     line2      exonic  gene-SLIV_00845,gene-SLIV_00850  CP009124.1   165960
# 2     line3      exonic  gene-SLIV_01525,gene-SLIV_01530  CP009124.1   317852
# 3     line4      exonic                  gene-SLIV_01805  CP009124.1   383979
# 4     line5      exonic                  gene-SLIV_03395  CP009124.1   719520
# ..      ...         ...                              ...         ...      ...
# 80   line81      exonic                  gene-SLIV_34330  CP009124.1  7606894
# 81   line82      exonic  gene-SLIV_34920,gene-SLIV_34925  CP009124.1  7727025
# 82   line83      exonic                  gene-SLIV_35965  CP009124.1  7954969
# 83   line84      exonic                  gene-SLIV_36250  CP009124.1  8032372
# 84   line85      exonic                  gene-SLIV_37085  CP009124.1  8218742
#
#        POS2  REF ALT TYPE of SV            SIZE of SV
# 0     92988    0   -   Deletion  DEL:a 270bp deletion
# 1    166239    0   -   Deletion  DEL:a 279bp deletion
# 2    318130    0   -   Deletion  DEL:a 278bp deletion
# 3    384257    0   -   Deletion  DEL:a 276bp deletion
# 4    719826    0   -   Deletion  DEL:a 294bp deletion
# ..      ...  ...  ..        ...                   ...
# 80  7607159    0   -   Deletion  DEL:a 268bp deletion
# 81  7727337    0   -   Deletion  DEL:a 320bp deletion
# 82  7955264    0   -   Deletion  DEL:a 290bp deletion
# 83  8032758    0   -   Deletion  DEL:a 392bp deletion
# 84  8219023    0   -   Deletion  DEL:a 287bp deletion
#
# [85 rows x 10 columns]

# %%
df_mut["size"] = df_mut["POS2"]- df_mut["POS1"]

# %%
df_mut
# Out:
#    #LINE_ID ANNO_REGION                       ANNOTATION       CHROM     POS1  \
# 0     line1      exonic                  gene-SLIV_00465  CP009124.1    92704
# 1     line2      exonic  gene-SLIV_00845,gene-SLIV_00850  CP009124.1   165960
# 2     line3      exonic  gene-SLIV_01525,gene-SLIV_01530  CP009124.1   317852
# 3     line4      exonic                  gene-SLIV_01805  CP009124.1   383979
# 4     line5      exonic                  gene-SLIV_03395  CP009124.1   719520
# ..      ...         ...                              ...         ...      ...
# 80   line81      exonic                  gene-SLIV_34330  CP009124.1  7606894
# 81   line82      exonic  gene-SLIV_34920,gene-SLIV_34925  CP009124.1  7727025
# 82   line83      exonic                  gene-SLIV_35965  CP009124.1  7954969
# 83   line84      exonic                  gene-SLIV_36250  CP009124.1  8032372
# 84   line85      exonic                  gene-SLIV_37085  CP009124.1  8218742
#
#        POS2  REF ALT TYPE of SV            SIZE of SV  size
# 0     92988    0   -   Deletion  DEL:a 270bp deletion   284
# 1    166239    0   -   Deletion  DEL:a 279bp deletion   279
# 2    318130    0   -   Deletion  DEL:a 278bp deletion   278
# 3    384257    0   -   Deletion  DEL:a 276bp deletion   278
# 4    719826    0   -   Deletion  DEL:a 294bp deletion   306
# ..      ...  ...  ..        ...                   ...   ...
# 80  7607159    0   -   Deletion  DEL:a 268bp deletion   265
# 81  7727337    0   -   Deletion  DEL:a 320bp deletion   312
# 82  7955264    0   -   Deletion  DEL:a 290bp deletion   295
# 83  8032758    0   -   Deletion  DEL:a 392bp deletion   386
# 84  8219023    0   -   Deletion  DEL:a 287bp deletion   281
#
# [85 rows x 11 columns]

# %%
df_mut.hist()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [54], in <module>
# ----> 1 df_mut.hist()
#
# File ~\.conda\envs\bio\lib\site-packages\pandas\plotting\_core.py:225, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     116 def hist_frame(
#     117     data: DataFrame,
#     118     column: IndexLabel = None,
#    (...)
#     133     **kwargs,
#     134 ):
#     135     """
#     136     Make a histogram of the DataFrame's columns.
#     137
#    (...)
#     223         >>> hist = df.hist(bins=3)
#     224     """
# --> 225     plot_backend = _get_plot_backend(backend)
#     226     return plot_backend.hist_frame(
#     227         data,
#     228         column=column,
#    (...)
#     242         **kwargs,
#     243     )
#
# File ~\.conda\envs\bio\lib\site-packages\pandas\plotting\_core.py:1849, in _get_plot_backend(backend)
#    1846 if backend in _backends:
#    1847     return _backends[backend]
# -> 1849 module = _load_backend(backend)
#    1850 _backends[backend] = module
#    1851 return module
#
# File ~\.conda\envs\bio\lib\site-packages\pandas\plotting\_core.py:1787, in _load_backend(backend)
#    1785         module = importlib.import_module("pandas.plotting._matplotlib")
#    1786     except ImportError:
# -> 1787         raise ImportError(
#    1788             "matplotlib is required for plotting when the "
#    1789             'default backend "matplotlib" is selected.'
#    1790         ) from None
#    1791     return module
#    1793 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
