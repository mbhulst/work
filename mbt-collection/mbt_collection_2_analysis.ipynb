# %% [markdown]
# # MBT collection

# %% [markdown]
# ### Extract BGC types
# Extract predicted BGC type from some antismash output

# %%
import os
import pandas as pd

from glob import glob
from collections import Counter

import my_functions as fun

# %%
# run this cell to use the input folder in current working directory
cwd = fun.cur_dir()
cwd_subfolders = fun.folders_in_directory2(cwd)

dir_input = 'not found'

for directory in cwd_subfolders:
    if directory.endswith("test"):
        dir_input = directory
        
print(dir_input)
# Out:
# C:\Users\mandy\Documents\Programming\mbt-collection\test

# %%
# run this cell to add a manual input folder
dir_input = "C:\\Users\\mandy\\OneDrive - Universiteit Leiden\\Data\\MBT collection\\Antismash results"

print(dir_input)
# Out:
# C:\Users\mandy\OneDrive - Universiteit Leiden\Data\MBT collection\Antismash results

# %%
# collect predicted bgc type from each bgc in all input subfolders

dict_bgc_types = dict()   # initialize dictionary to store data

input_subfolders = fun.folders_in_directory2(dir_input)   # get list of folders to search through

for directory in input_subfolders:
    subfoldername = os.path.basename(directory)   # extract strain name from folder name
    dict_hits = fun.predicted_bgc_types(directory)   # get dict of predicted bgc types for each strain
    dict_bgc_types[subfoldername] = dict_hits   # collect predicted bgc types in a dictionary

# %%
# extract the number of bgcs of each type present in each strain

dict_all = dict()   # initailize dictionary to store data

for strain in dict_bgc_types:

    bgc_types = []   # initialize list to store predicted bgc types
    
    for bgc in dict_bgc_types[strain]:
        bgc_types.append(dict_bgc_types[strain][bgc])   # collect all bgc types in this strain
    
    bgc_types_flat = [item for sublist in bgc_types for item in sublist]   # convert list of lists to flat list
    
    # count how often each bgc type occurs in this strain
    all_types = Counter(bgc_types_flat).keys()
    all_types_counted = Counter(bgc_types_flat).values()
    
    #  collect all types of bgcs in one dictionary
    dict_bgc_types_count = dict(zip(all_types, all_types_counted))
    dict_all[strain] = dict_bgc_types_count

# %%
df_bgcs = pd.DataFrame(dict_all)
df_bgcs = df_bgcs.fillna(0)

# %%
df_bgcs = df_bgcs.transpose()

# %%
with open('dmDoxo.txt') as f:
  dict_dmDoxo = dict(x.rstrip().split(None, 1) for x in f)

df_bgcs["dmDoxo"] = pd.Series(dict_dmDoxo)

# %%
dict_dmDoxo
### NOTE: the numbers should be converted to integers!!!
# Out:
# {'MBT1': '4',
#  'MBT3': '5',
#  'MBT5': '0',
#  'MBT7': '0',
#  'MBT10': '0',
#  'MBT12': '4',
#  'MBT13': '0',
#  'MBT14': '0',
#  'MBT21': '0',
#  'MBT34': '4',
#  'MBT37': '5',
#  'MBT38': '0',
#  'MBT39': '0',
#  'MBT44': '5',
#  'MBT47': '0',
#  'Hm77': '0',
#  'Hm107': '4',
#  'Hm108': '4',
#  'Hm111': '4',
#  'MBT63': '0',
#  'MBT64': '0',
#  'Hm129': '4',
#  'Hm155': '5',
#  'MBT74': '5',
#  'MBT77': '0',
#  'MBT82': '0',
#  'MBT90': '0',
#  'DSM40127': '5',
#  'Go-475': '5',
#  'Streptomyces-scopuliridis': '0',
#  'CS057': '5',
#  'MBT27': '0'}

# %%
df_bgcs
# Out:
#                            T1PKS  NRPS  NRPS-like  lanthipeptide-class-iv  \
# CS057                        5.0  10.0        3.0                     1.0
# DSM40127                    16.0  21.0        8.0                     0.0
# Go-475                       6.0   6.0        3.0                     0.0
# Hm107                        3.0   8.0        3.0                     0.0
# Hm108                        4.0   7.0        2.0                     0.0
# Hm111                        3.0   7.0        3.0                     0.0
# Hm129                        3.0   8.0        3.0                     0.0
# Hm155                        4.0   7.0        3.0                     0.0
# Hm77                         6.0   7.0        1.0                     0.0
# MBT1                        16.0   6.0        4.0                     0.0
# MBT10                       10.0  13.0        3.0                     0.0
# MBT12                       12.0   5.0        3.0                     0.0
# MBT13                        8.0  12.0        3.0                     0.0
# MBT14                        0.0   7.0        5.0                     0.0
# MBT21                        3.0   9.0        1.0                     0.0
# MBT27                        2.0  20.0        5.0                     2.0
# MBT3                        16.0   6.0        3.0                     0.0
# MBT34                        6.0  20.0        4.0                     1.0
# MBT37                        5.0   8.0        2.0                     1.0
# MBT38                       16.0   5.0        4.0                     0.0
# MBT39                       28.0  24.0        8.0                     0.0
# MBT44                        6.0  20.0        2.0                     1.0
# MBT47                        2.0  14.0        7.0                     0.0
# MBT5                        13.0   5.0        4.0                     0.0
# MBT63                       10.0   7.0        3.0                     1.0
# MBT64                       14.0  13.0       11.0                     2.0
# MBT7                         6.0  10.0        2.0                     1.0
# MBT74                        2.0   2.0        1.0                     0.0
# MBT77                        3.0   9.0        5.0                     0.0
# MBT82                        3.0   9.0        1.0                     1.0
# MBT90                        2.0   7.0        3.0                     0.0
# Streptomyces-scopuliridis    7.0  13.0        3.0                     0.0
#
#                            transAT-PKS  T3PKS  melanin  RiPP-like  terpene  \
# CS057                              1.0    2.0      2.0        2.0      5.0
# DSM40127                           0.0    3.0      0.0        2.0      6.0
# Go-475                             0.0    1.0      2.0        2.0      8.0
# Hm107                              0.0    2.0      1.0        2.0      6.0
# Hm108                              0.0    2.0      1.0        2.0      6.0
# Hm111                              0.0    2.0      1.0        2.0      6.0
# Hm129                              0.0    2.0      1.0        2.0      5.0
# Hm155                              0.0    2.0      1.0        2.0      7.0
# Hm77                               0.0    0.0      1.0        1.0      6.0
# MBT1                               0.0    1.0      1.0        2.0      8.0
# MBT10                              0.0    0.0      1.0        2.0      6.0
# MBT12                              0.0    1.0      1.0        2.0      7.0
# MBT13                              0.0    1.0      2.0        1.0      7.0
# MBT14                              0.0    1.0      1.0        3.0      7.0
# MBT21                              0.0    0.0      2.0        2.0      7.0
# MBT27                              0.0    3.0      1.0        4.0      6.0
# MBT3                               0.0    1.0      1.0        2.0      8.0
# MBT34                              1.0    3.0      2.0        2.0      6.0
# MBT37                              0.0    2.0      1.0        2.0      7.0
# MBT38                              0.0    1.0      1.0        2.0      7.0
# MBT39                              0.0    4.0      2.0        6.0     13.0
# MBT44                              0.0    3.0      1.0        2.0      4.0
# MBT47                              0.0    1.0      1.0        5.0      5.0
# MBT5                               0.0    1.0      1.0        2.0      7.0
# MBT63                              0.0    3.0      2.0        2.0      8.0
# MBT64                              0.0    3.0      1.0        3.0      8.0
# MBT7                               0.0    0.0      2.0        2.0      6.0
# MBT74                              0.0    2.0      1.0        2.0      3.0
# MBT77                              0.0    2.0      2.0        2.0      5.0
# MBT82                              0.0    1.0      2.0        2.0      7.0
# MBT90                              0.0    2.0      2.0        2.0      5.0
# Streptomyces-scopuliridis          0.0    2.0      1.0        1.0      5.0
#
#                            T2PKS  ...  linaridin  transAT-PKS-like  \
# CS057                        1.0  ...        0.0               0.0
# DSM40127                     2.0  ...        0.0               0.0
# Go-475                       2.0  ...        0.0               0.0
# Hm107                        1.0  ...        0.0               0.0
# Hm108                        1.0  ...        0.0               0.0
# Hm111                        1.0  ...        0.0               0.0
# Hm129                        1.0  ...        0.0               0.0
# Hm155                        1.0  ...        0.0               0.0
# Hm77                         3.0  ...        0.0               0.0
# MBT1                         2.0  ...        0.0               0.0
# MBT10                        1.0  ...        0.0               0.0
# MBT12                        3.0  ...        0.0               0.0
# MBT13                        2.0  ...        0.0               0.0
# MBT14                        2.0  ...        0.0               0.0
# MBT21                        1.0  ...        0.0               0.0
# MBT27                        1.0  ...        0.0               0.0
# MBT3                         4.0  ...        0.0               0.0
# MBT34                        1.0  ...        1.0               1.0
# MBT37                        0.0  ...        0.0               0.0
# MBT38                        3.0  ...        0.0               0.0
# MBT39                        2.0  ...        3.0               0.0
# MBT44                        2.0  ...        0.0               0.0
# MBT47                        2.0  ...        1.0               0.0
# MBT5                         2.0  ...        0.0               0.0
# MBT63                        1.0  ...        0.0               0.0
# MBT64                        2.0  ...        0.0               0.0
# MBT7                         2.0  ...        1.0               0.0
# MBT74                        1.0  ...        0.0               0.0
# MBT77                        0.0  ...        0.0               0.0
# MBT82                        1.0  ...        1.0               0.0
# MBT90                        0.0  ...        0.0               0.0
# Streptomyces-scopuliridis    1.0  ...        1.0               0.0
#
#                            nucleoside  thioamide-NRP  phenazine  \
# CS057                             0.0            0.0        0.0
# DSM40127                          0.0            0.0        0.0
# Go-475                            0.0            0.0        0.0
# Hm107                             0.0            0.0        0.0
# Hm108                             0.0            0.0        0.0
# Hm111                             0.0            0.0        0.0
# Hm129                             0.0            0.0        0.0
# Hm155                             0.0            0.0        0.0
# Hm77                              0.0            0.0        0.0
# MBT1                              0.0            0.0        0.0
# MBT10                             0.0            0.0        0.0
# MBT12                             0.0            0.0        0.0
# MBT13                             0.0            0.0        0.0
# MBT14                             0.0            0.0        0.0
# MBT21                             0.0            0.0        0.0
# MBT27                             0.0            0.0        0.0
# MBT3                              0.0            0.0        0.0
# MBT34                             0.0            0.0        0.0
# MBT37                             0.0            0.0        0.0
# MBT38                             0.0            0.0        0.0
# MBT39                             1.0            0.0        0.0
# MBT44                             0.0            1.0        1.0
# MBT47                             0.0            0.0        0.0
# MBT5                              0.0            0.0        0.0
# MBT63                             2.0            0.0        0.0
# MBT64                             0.0            0.0        1.0
# MBT7                              0.0            0.0        0.0
# MBT74                             0.0            0.0        1.0
# MBT77                             0.0            0.0        0.0
# MBT82                             0.0            0.0        0.0
# MBT90                             0.0            0.0        0.0
# Streptomyces-scopuliridis         1.0            0.0        0.0
#
#                            guanidinotides  redox-cofactor  thioamitides  \
# CS057                                 0.0             0.0           0.0
# DSM40127                              0.0             0.0           0.0
# Go-475                                0.0             0.0           0.0
# Hm107                                 0.0             0.0           0.0
# Hm108                                 0.0             0.0           0.0
# Hm111                                 0.0             0.0           0.0
# Hm129                                 0.0             0.0           0.0
# Hm155                                 0.0             0.0           0.0
# Hm77                                  0.0             0.0           0.0
# MBT1                                  0.0             0.0           0.0
# MBT10                                 0.0             0.0           0.0
# MBT12                                 0.0             0.0           0.0
# MBT13                                 0.0             0.0           0.0
# MBT14                                 0.0             0.0           0.0
# MBT21                                 0.0             0.0           0.0
# MBT27                                 0.0             0.0           0.0
# MBT3                                  0.0             0.0           0.0
# MBT34                                 0.0             0.0           0.0
# MBT37                                 0.0             0.0           0.0
# MBT38                                 0.0             0.0           0.0
# MBT39                                 0.0             0.0           0.0
# MBT44                                 0.0             0.0           0.0
# MBT47                                 0.0             0.0           0.0
# MBT5                                  0.0             0.0           0.0
# MBT63                                 1.0             0.0           0.0
# MBT64                                 0.0             1.0           0.0
# MBT7                                  0.0             0.0           0.0
# MBT74                                 0.0             0.0           0.0
# MBT77                                 0.0             1.0           0.0
# MBT82                                 0.0             0.0           0.0
# MBT90                                 0.0             1.0           1.0
# Streptomyces-scopuliridis             0.0             0.0           0.0
#
#                            prodigiosin  dmDoxo
# CS057                              0.0       5
# DSM40127                           0.0       5
# Go-475                             0.0       5
# Hm107                              0.0       4
# Hm108                              0.0       4
# Hm111                              0.0       4
# Hm129                              0.0       4
# Hm155                              0.0       5
# Hm77                               0.0       0
# MBT1                               0.0       4
# MBT10                              0.0       0
# MBT12                              0.0       4
# MBT13                              0.0       0
# MBT14                              0.0       0
# MBT21                              0.0       0
# MBT27                              0.0       0
# MBT3                               0.0       5
# MBT34                              0.0       4
# MBT37                              0.0       5
# MBT38                              0.0       0
# MBT39                              0.0       0
# MBT44                              0.0       5
# MBT47                              0.0       0
# MBT5                               0.0       0
# MBT63                              0.0       0
# MBT64                              0.0       0
# MBT7                               0.0       0
# MBT74                              0.0       5
# MBT77                              0.0       0
# MBT82                              0.0       0
# MBT90                              0.0       0
# Streptomyces-scopuliridis          1.0       0
#
# [32 rows x 47 columns]

# %%
df_bgcs[df_bgcs["dmDoxo"] == '0']
# Out:
#                            T1PKS  NRPS  NRPS-like  lanthipeptide-class-iv  \
# Hm77                         6.0   7.0        1.0                     0.0
# MBT10                       10.0  13.0        3.0                     0.0
# MBT13                        8.0  12.0        3.0                     0.0
# MBT14                        0.0   7.0        5.0                     0.0
# MBT21                        3.0   9.0        1.0                     0.0
# MBT27                        2.0  20.0        5.0                     2.0
# MBT38                       16.0   5.0        4.0                     0.0
# MBT39                       28.0  24.0        8.0                     0.0
# MBT47                        2.0  14.0        7.0                     0.0
# MBT5                        13.0   5.0        4.0                     0.0
# MBT63                       10.0   7.0        3.0                     1.0
# MBT64                       14.0  13.0       11.0                     2.0
# MBT7                         6.0  10.0        2.0                     1.0
# MBT77                        3.0   9.0        5.0                     0.0
# MBT82                        3.0   9.0        1.0                     1.0
# MBT90                        2.0   7.0        3.0                     0.0
# Streptomyces-scopuliridis    7.0  13.0        3.0                     0.0
#
#                            transAT-PKS  T3PKS  melanin  RiPP-like  terpene  \
# Hm77                               0.0    0.0      1.0        1.0      6.0
# MBT10                              0.0    0.0      1.0        2.0      6.0
# MBT13                              0.0    1.0      2.0        1.0      7.0
# MBT14                              0.0    1.0      1.0        3.0      7.0
# MBT21                              0.0    0.0      2.0        2.0      7.0
# MBT27                              0.0    3.0      1.0        4.0      6.0
# MBT38                              0.0    1.0      1.0        2.0      7.0
# MBT39                              0.0    4.0      2.0        6.0     13.0
# MBT47                              0.0    1.0      1.0        5.0      5.0
# MBT5                               0.0    1.0      1.0        2.0      7.0
# MBT63                              0.0    3.0      2.0        2.0      8.0
# MBT64                              0.0    3.0      1.0        3.0      8.0
# MBT7                               0.0    0.0      2.0        2.0      6.0
# MBT77                              0.0    2.0      2.0        2.0      5.0
# MBT82                              0.0    1.0      2.0        2.0      7.0
# MBT90                              0.0    2.0      2.0        2.0      5.0
# Streptomyces-scopuliridis          0.0    2.0      1.0        1.0      5.0
#
#                            T2PKS  ...  linaridin  transAT-PKS-like  \
# Hm77                         3.0  ...        0.0               0.0
# MBT10                        1.0  ...        0.0               0.0
# MBT13                        2.0  ...        0.0               0.0
# MBT14                        2.0  ...        0.0               0.0
# MBT21                        1.0  ...        0.0               0.0
# MBT27                        1.0  ...        0.0               0.0
# MBT38                        3.0  ...        0.0               0.0
# MBT39                        2.0  ...        3.0               0.0
# MBT47                        2.0  ...        1.0               0.0
# MBT5                         2.0  ...        0.0               0.0
# MBT63                        1.0  ...        0.0               0.0
# MBT64                        2.0  ...        0.0               0.0
# MBT7                         2.0  ...        1.0               0.0
# MBT77                        0.0  ...        0.0               0.0
# MBT82                        1.0  ...        1.0               0.0
# MBT90                        0.0  ...        0.0               0.0
# Streptomyces-scopuliridis    1.0  ...        1.0               0.0
#
#                            nucleoside  thioamide-NRP  phenazine  \
# Hm77                              0.0            0.0        0.0
# MBT10                             0.0            0.0        0.0
# MBT13                             0.0            0.0        0.0
# MBT14                             0.0            0.0        0.0
# MBT21                             0.0            0.0        0.0
# MBT27                             0.0            0.0        0.0
# MBT38                             0.0            0.0        0.0
# MBT39                             1.0            0.0        0.0
# MBT47                             0.0            0.0        0.0
# MBT5                              0.0            0.0        0.0
# MBT63                             2.0            0.0        0.0
# MBT64                             0.0            0.0        1.0
# MBT7                              0.0            0.0        0.0
# MBT77                             0.0            0.0        0.0
# MBT82                             0.0            0.0        0.0
# MBT90                             0.0            0.0        0.0
# Streptomyces-scopuliridis         1.0            0.0        0.0
#
#                            guanidinotides  redox-cofactor  thioamitides  \
# Hm77                                  0.0             0.0           0.0
# MBT10                                 0.0             0.0           0.0
# MBT13                                 0.0             0.0           0.0
# MBT14                                 0.0             0.0           0.0
# MBT21                                 0.0             0.0           0.0
# MBT27                                 0.0             0.0           0.0
# MBT38                                 0.0             0.0           0.0
# MBT39                                 0.0             0.0           0.0
# MBT47                                 0.0             0.0           0.0
# MBT5                                  0.0             0.0           0.0
# MBT63                                 1.0             0.0           0.0
# MBT64                                 0.0             1.0           0.0
# MBT7                                  0.0             0.0           0.0
# MBT77                                 0.0             1.0           0.0
# MBT82                                 0.0             0.0           0.0
# MBT90                                 0.0             1.0           1.0
# Streptomyces-scopuliridis             0.0             0.0           0.0
#
#                            prodigiosin  dmDoxo
# Hm77                               0.0       0
# MBT10                              0.0       0
# MBT13                              0.0       0
# MBT14                              0.0       0
# MBT21                              0.0       0
# MBT27                              0.0       0
# MBT38                              0.0       0
# MBT39                              0.0       0
# MBT47                              0.0       0
# MBT5                               0.0       0
# MBT63                              0.0       0
# MBT64                              0.0       0
# MBT7                               0.0       0
# MBT77                              0.0       0
# MBT82                              0.0       0
# MBT90                              0.0       0
# Streptomyces-scopuliridis          1.0       0
#
# [17 rows x 47 columns]

# %%
dict_bgc_types
# Out:
# {'CS057': {'NEVF01000001.1.region001.gbk': ['T1PKS', 'NRPS'],
#   'NEVF01000001.1.region002.gbk': ['NRPS-like', 'lanthipeptide-class-iv'],
#   'NEVF01000002.1.region001.gbk': ['transAT-PKS'],
#   'NEVF01000002.1.region002.gbk': ['NRPS', 'T3PKS'],
#   'NEVF01000002.1.region003.gbk': ['melanin'],
#   'NEVF01000002.1.region004.gbk': ['NRPS', 'T1PKS'],
#   'NEVF01000002.1.region005.gbk': ['T1PKS'],
#   'NEVF01000003.1.region001.gbk': ['RiPP-like'],
#   'NEVF01000003.1.region002.gbk': ['NRPS', 'T1PKS'],
#   'NEVF01000003.1.region003.gbk': ['NRPS', 'NRPS-like'],
#   'NEVF01000003.1.region004.gbk': ['terpene'],
#   'NEVF01000004.1.region001.gbk': ['terpene'],
#   'NEVF01000005.1.region001.gbk': ['RiPP-like'],
#   'NEVF01000006.1.region001.gbk': ['T2PKS', 'oligosaccharide', 'NRPS'],
#   'NEVF01000006.1.region002.gbk': ['siderophore'],
#   'NEVF01000010.1.region001.gbk': ['terpene'],
#   'NEVF01000012.1.region001.gbk': ['lanthipeptide-class-iii'],
#   'NEVF01000012.1.region002.gbk': ['melanin'],
#   'NEVF01000012.1.region003.gbk': ['thiopeptide', 'LAP'],
#   'NEVF01000012.1.region004.gbk': ['NRPS-like'],
#   'NEVF01000015.1.region001.gbk': ['ectoine',
#    'butyrolactone',
#    'ladderane',
#    'arylpolyene',
#    'NRPS',
#    'T1PKS'],
#   'NEVF01000022.1.region001.gbk': ['ectoine'],
#   'NEVF01000030.1.region001.gbk': ['siderophore'],
#   'NEVF01000030.1.region002.gbk': ['lanthipeptide-class-iii',
#    'lanthipeptide-class-ii'],
#   'NEVF01000030.1.region003.gbk': ['lanthipeptide-class-ii',
#    'RRE-containing',
#    'NRPS'],
#   'NEVF01000034.1.region001.gbk': ['ectoine'],
#   'NEVF01000038.1.region001.gbk': ['terpene'],
#   'NEVF01000041.1.region001.gbk': ['NRPS'],
#   'NEVF01000041.1.region002.gbk': ['thiopeptide', 'LAP'],
#   'NEVF01000043.1.region001.gbk': ['T3PKS'],
#   'NEVF01000046.1.region001.gbk': ['NRPS'],
#   'NEVF01000047.1.region001.gbk': ['terpene'],
#   'NEVF01000047.1.region002.gbk': ['butyrolactone']},
#  'DSM40127': {'LBHA01000018.1.region001.gbk': ['T1PKS', 'NRPS'],
#   'LBHA01000022.1.region001.gbk': ['LAP'],
#   'LBHA01000037.1.region001.gbk': ['blactam'],
#   'LBHA01000038.1.region001.gbk': ['lanthipeptide-class-ii'],
#   'LBHA01000057.1.region001.gbk': ['NRPS', 'T1PKS'],
#   'LBHA01000070.1.region001.gbk': ['NRPS-like', 'T1PKS'],
#   'LBHA01000079.1.region001.gbk': ['siderophore'],
#   'LBHA01000080.1.region001.gbk': ['thiopeptide', 'LAP'],
#   'LBHA01000082.1.region001.gbk': ['terpene'],
#   'LBHA01000087.1.region001.gbk': ['NRPS'],
#   'LBHA01000099.1.region001.gbk': ['T2PKS'],
#   'LBHA01000100.1.region001.gbk': ['PKS-like'],
#   'LBHA01000106.1.region001.gbk': ['NRPS'],
#   'LBHA01000110.1.region001.gbk': ['NRPS'],
#   'LBHA01000153.1.region001.gbk': ['NRPS'],
#   'LBHA01000157.1.region001.gbk': ['NRPS'],
#   'LBHA01000161.1.region001.gbk': ['hglE-KS', 'T1PKS'],
#   'LBHA01000184.1.region001.gbk': ['ranthipeptide'],
#   'LBHA01000188.1.region001.gbk': ['T3PKS'],
#   'LBHA01000197.1.region001.gbk': ['T1PKS', 'NRPS-like'],
#   'LBHA01000212.1.region001.gbk': ['NRPS'],
#   'LBHA01000263.1.region001.gbk': ['T1PKS', 'NRPS-like'],
#   'LBHA01000270.1.region001.gbk': ['terpene'],
#   'LBHA01000276.1.region001.gbk': ['T2PKS'],
#   'LBHA01000279.1.region001.gbk': ['T1PKS'],
#   'LBHA01000280.1.region001.gbk': ['T1PKS'],
#   'LBHA01000281.1.region001.gbk': ['T1PKS'],
#   'LBHA01000295.1.region001.gbk': ['butyrolactone'],
#   'LBHA01000323.1.region001.gbk': ['terpene'],
#   'LBHA01000324.1.region001.gbk': ['terpene'],
#   'LBHA01000330.1.region001.gbk': ['T3PKS', 'NRPS'],
#   'LBHA01000334.1.region001.gbk': ['butyrolactone'],
#   'LBHA01000349.1.region001.gbk': ['NRPS'],
#   'LBHA01000358.1.region001.gbk': ['NRPS'],
#   'LBHA01000370.1.region001.gbk': ['NRPS', 'NRPS-like'],
#   'LBHA01000378.1.region001.gbk': ['NRPS'],
#   'LBHA01000390.1.region001.gbk': ['T1PKS'],
#   'LBHA01000415.1.region001.gbk': ['RiPP-like'],
#   'LBHA01000420.1.region001.gbk': ['T3PKS'],
#   'LBHA01000422.1.region001.gbk': ['NRPS-like'],
#   'LBHA01000425.1.region001.gbk': ['T1PKS'],
#   'LBHA01000429.1.region001.gbk': ['NRPS'],
#   'LBHA01000448.1.region001.gbk': ['T1PKS'],
#   'LBHA01000468.1.region001.gbk': ['T1PKS'],
#   'LBHA01000475.1.region001.gbk': ['furan'],
#   'LBHA01000480.1.region001.gbk': ['NRPS'],
#   'LBHA01000483.1.region001.gbk': ['T1PKS'],
#   'LBHA01000488.1.region001.gbk': ['NRPS'],
#   'LBHA01000502.1.region001.gbk': ['terpene'],
#   'LBHA01000527.1.region001.gbk': ['T1PKS'],
#   'LBHA01000544.1.region001.gbk': ['NRPS'],
#   'LBHA01000555.1.region001.gbk': ['siderophore'],
#   'LBHA01000560.1.region001.gbk': ['NRPS-like'],
#   'LBHA01000622.1.region001.gbk': ['lanthipeptide-class-iii'],
#   'LBHA01000659.1.region001.gbk': ['terpene'],
#   'LBHA01000675.1.region001.gbk': ['butyrolactone'],
#   'LBHA01000717.1.region001.gbk': ['siderophore'],
#   'LBHA01000791.1.region001.gbk': ['NRPS'],
#   'LBHA01000798.1.region001.gbk': ['T1PKS'],
#   'LBHA01000799.1.region001.gbk': ['NRPS', 'NRPS-like'],
#   'LBHA01000846.1.region001.gbk': ['RiPP-like'],
#   'LBHA01000866.1.region001.gbk': ['NAPAA'],
#   'LBHA01000893.1.region001.gbk': ['NRPS'],
#   'LBHA01000898.1.region001.gbk': ['siderophore'],
#   'LBHA01000934.1.region001.gbk': ['NRPS-like'],
#   'LBHA01000961.1.region001.gbk': ['NRPS']},
#  'Go-475': {'CP026121.1.region001.gbk': ['NRPS', 'T1PKS'],
#   'CP026121.1.region002.gbk': ['melanin'],
#   'CP026121.1.region003.gbk': ['NRPS'],
#   'CP026121.1.region004.gbk': ['NAPAA'],
#   'CP026121.1.region005.gbk': ['terpene', 'lanthipeptide-class-iii'],
#   'CP026121.1.region006.gbk': ['T3PKS'],
#   'CP026121.1.region007.gbk': ['lassopeptide'],
#   'CP026121.1.region008.gbk': ['ectoine'],
#   'CP026121.1.region009.gbk': ['terpene'],
#   'CP026121.1.region010.gbk': ['T1PKS', 'NRPS'],
#   'CP026121.1.region011.gbk': ['terpene'],
#   'CP026121.1.region012.gbk': ['melanin'],
#   'CP026121.1.region013.gbk': ['lassopeptide'],
#   'CP026121.1.region014.gbk': ['siderophore'],
#   'CP026121.1.region015.gbk': ['butyrolactone'],
#   'CP026121.1.region016.gbk': ['T1PKS', 'NRPS-like', 'NRPS'],
#   'CP026121.1.region017.gbk': ['phosphonate'],
#   'CP026121.1.region018.gbk': ['terpene'],
#   'CP026121.1.region019.gbk': ['amglyccycl'],
#   'CP026121.1.region020.gbk': ['NRPS',
#    'NRPS-like',
#    'T2PKS',
#    'oligosaccharide'],
#   'CP026121.1.region021.gbk': ['terpene'],
#   'CP026121.1.region022.gbk': ['terpene'],
#   'CP026121.1.region023.gbk': ['siderophore'],
#   'CP026121.1.region024.gbk': ['RiPP-like'],
#   'CP026121.1.region025.gbk': ['terpene'],
#   'CP026121.1.region026.gbk': ['T1PKS', 'NRPS', 'other'],
#   'CP026121.1.region027.gbk': ['T2PKS', 'siderophore'],
#   'CP026121.1.region028.gbk': ['terpene'],
#   'CP026121.1.region029.gbk': ['NRPS-like', 'T1PKS'],
#   'CP026121.1.region030.gbk': ['RiPP-like', 'lanthipeptide-class-iii'],
#   'CP026121.1.region031.gbk': ['T1PKS']},
#  'Hm107': {'contig_00003.region001.gbk': ['T3PKS'],
#   'contig_00005.region001.gbk': ['NRPS'],
#   'contig_00006.region001.gbk': ['terpene'],
#   'contig_00016.region001.gbk': ['NRPS'],
#   'contig_00019.region001.gbk': ['ectoine', 'butyrolactone'],
#   'contig_00020.region001.gbk': ['T2PKS', 'T1PKS', 'PKS-like'],
#   'contig_00023.region001.gbk': ['siderophore'],
#   'contig_00026.region001.gbk': ['PKS-like', 'butyrolactone'],
#   'contig_00029.region001.gbk': ['T3PKS'],
#   'contig_00038.region001.gbk': ['NRPS', 'terpene'],
#   'contig_00049.region001.gbk': ['NRPS'],
#   'contig_00051.region001.gbk': ['RRE-containing'],
#   'contig_00066.region001.gbk': ['butyrolactone'],
#   'contig_00083.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00090.region001.gbk': ['terpene', 'NAPAA'],
#   'contig_00092.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00112.region001.gbk': ['NRPS'],
#   'contig_00123.region001.gbk': ['siderophore'],
#   'contig_00137.region001.gbk': ['NRPS', 'NRPS-like', 'T1PKS'],
#   'contig_00138.region001.gbk': ['NRPS'],
#   'contig_00142.region001.gbk': ['ectoine'],
#   'contig_00170.region001.gbk': ['melanin'],
#   'contig_00175.region001.gbk': ['NRPS-like'],
#   'contig_00183.region001.gbk': ['T1PKS'],
#   'contig_00198.region001.gbk': ['NRPS-like'],
#   'contig_00207.region001.gbk': ['terpene'],
#   'contig_00219.region001.gbk': ['terpene'],
#   'contig_00258.region001.gbk': ['RiPP-like'],
#   'contig_00276.region001.gbk': ['NRPS'],
#   'contig_00344.region001.gbk': ['RiPP-like'],
#   'contig_00371.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00417.region001.gbk': ['terpene']},
#  'Hm108': {'contig_00010.region001.gbk': ['NRPS'],
#   'contig_00010.region002.gbk': ['T2PKS', 'PKS-like', 'T1PKS'],
#   'contig_00013.region001.gbk': ['butyrolactone'],
#   'contig_00021.region001.gbk': ['T3PKS'],
#   'contig_00022.region001.gbk': ['NRPS'],
#   'contig_00028.region001.gbk': ['T3PKS'],
#   'contig_00030.region001.gbk': ['T1PKS'],
#   'contig_00031.region001.gbk': ['terpene'],
#   'contig_00036.region001.gbk': ['butyrolactone', 'ectoine'],
#   'contig_00045.region001.gbk': ['NRPS'],
#   'contig_00052.region001.gbk': ['ectoine'],
#   'contig_00053.region001.gbk': ['NRPS', 'terpene'],
#   'contig_00059.region001.gbk': ['NRPS'],
#   'contig_00086.region001.gbk': ['melanin'],
#   'contig_00095.region001.gbk': ['RiPP-like'],
#   'contig_00116.region001.gbk': ['siderophore'],
#   'contig_00117.region001.gbk': ['NRPS'],
#   'contig_00128.region001.gbk': ['siderophore'],
#   'contig_00131.region001.gbk': ['PKS-like', 'butyrolactone'],
#   'contig_00172.region001.gbk': ['terpene'],
#   'contig_00174.region001.gbk': ['NRPS'],
#   'contig_00191.region001.gbk': ['terpene'],
#   'contig_00194.region001.gbk': ['T1PKS'],
#   'contig_00198.region001.gbk': ['NRPS-like'],
#   'contig_00205.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00207.region001.gbk': ['NRPS-like'],
#   'contig_00268.region001.gbk': ['terpene'],
#   'contig_00281.region001.gbk': ['RiPP-like'],
#   'contig_00306.region001.gbk': ['T1PKS'],
#   'contig_00328.region001.gbk': ['terpene'],
#   'contig_00361.region001.gbk': ['lassopeptide'],
#   'contig_00387.region001.gbk': ['lanthipeptide-class-iii']},
#  'Hm111': {'contig_00001.region001.gbk': ['T2PKS', 'T1PKS', 'PKS-like'],
#   'contig_00001.region002.gbk': ['NRPS'],
#   'contig_00002.region001.gbk': ['T3PKS'],
#   'contig_00014.region001.gbk': ['NAPAA', 'terpene'],
#   'contig_00015.region001.gbk': ['T1PKS', 'NRPS-like', 'NRPS'],
#   'contig_00020.region001.gbk': ['terpene'],
#   'contig_00025.region001.gbk': ['PKS-like', 'butyrolactone'],
#   'contig_00026.region001.gbk': ['NRPS'],
#   'contig_00033.region001.gbk': ['siderophore'],
#   'contig_00042.region001.gbk': ['NRPS', 'terpene'],
#   'contig_00049.region001.gbk': ['ectoine'],
#   'contig_00053.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00059.region001.gbk': ['lassopeptide'],
#   'contig_00071.region001.gbk': ['butyrolactone'],
#   'contig_00076.region001.gbk': ['T3PKS'],
#   'contig_00106.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00117.region001.gbk': ['butyrolactone', 'ectoine'],
#   'contig_00120.region001.gbk': ['NRPS'],
#   'contig_00135.region001.gbk': ['siderophore'],
#   'contig_00173.region001.gbk': ['melanin'],
#   'contig_00191.region001.gbk': ['T1PKS'],
#   'contig_00207.region001.gbk': ['terpene'],
#   'contig_00229.region001.gbk': ['NRPS-like'],
#   'contig_00247.region001.gbk': ['terpene'],
#   'contig_00251.region001.gbk': ['NRPS'],
#   'contig_00282.region001.gbk': ['NRPS'],
#   'contig_00298.region001.gbk': ['terpene'],
#   'contig_00359.region001.gbk': ['RiPP-like'],
#   'contig_00397.region001.gbk': ['RiPP-like'],
#   'contig_00420.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00563.region001.gbk': ['NRPS-like']},
#  'Hm129': {'contig_00001.region001.gbk': ['T3PKS'],
#   'contig_00002.region001.gbk': ['lassopeptide'],
#   'contig_00003.region001.gbk': ['siderophore'],
#   'contig_00010.region001.gbk': ['T3PKS'],
#   'contig_00013.region001.gbk': ['T2PKS', 'PKS-like', 'T1PKS'],
#   'contig_00021.region001.gbk': ['NRPS', 'NRPS-like', 'T1PKS'],
#   'contig_00030.region001.gbk': ['NRPS'],
#   'contig_00031.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00039.region001.gbk': ['ectoine'],
#   'contig_00062.region001.gbk': ['ectoine', 'butyrolactone'],
#   'contig_00075.region001.gbk': ['terpene'],
#   'contig_00077.region001.gbk': ['NRPS', 'terpene'],
#   'contig_00094.region001.gbk': ['NRPS'],
#   'contig_00096.region001.gbk': ['terpene'],
#   'contig_00104.region001.gbk': ['PKS-like', 'butyrolactone'],
#   'contig_00105.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00109.region001.gbk': ['butyrolactone'],
#   'contig_00127.region001.gbk': ['siderophore'],
#   'contig_00129.region001.gbk': ['NRPS'],
#   'contig_00143.region001.gbk': ['NRPS'],
#   'contig_00146.region001.gbk': ['NRPS-like'],
#   'contig_00150.region001.gbk': ['NRPS'],
#   'contig_00154.region001.gbk': ['NRPS'],
#   'contig_00161.region001.gbk': ['terpene'],
#   'contig_00178.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00199.region001.gbk': ['NRPS-like'],
#   'contig_00233.region001.gbk': ['RiPP-like'],
#   'contig_00313.region001.gbk': ['melanin'],
#   'contig_00323.region001.gbk': ['NAPAA'],
#   'contig_00358.region001.gbk': ['RiPP-like'],
#   'contig_00379.region001.gbk': ['terpene'],
#   'contig_00420.region001.gbk': ['T1PKS']},
#  'Hm155': {'contig_00001.region001.gbk': ['T3PKS'],
#   'contig_00002.region001.gbk': ['T2PKS', 'T1PKS', 'PKS-like'],
#   'contig_00002.region002.gbk': ['NRPS'],
#   'contig_00002.region003.gbk': ['NRPS'],
#   'contig_00011.region001.gbk': ['siderophore'],
#   'contig_00012.region001.gbk': ['terpene'],
#   'contig_00013.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00016.region001.gbk': ['lassopeptide'],
#   'contig_00019.region001.gbk': ['NRPS', 'NRPS-like', 'T1PKS'],
#   'contig_00024.region001.gbk': ['RiPP-like'],
#   'contig_00031.region001.gbk': ['PKS-like', 'butyrolactone'],
#   'contig_00045.region001.gbk': ['siderophore'],
#   'contig_00056.region001.gbk': ['butyrolactone', 'ectoine'],
#   'contig_00058.region001.gbk': ['NRPS', 'terpene'],
#   'contig_00064.region001.gbk': ['ectoine'],
#   'contig_00069.region001.gbk': ['NAPAA', 'terpene'],
#   'contig_00089.region001.gbk': ['T1PKS'],
#   'contig_00119.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00122.region001.gbk': ['melanin'],
#   'contig_00129.region001.gbk': ['butyrolactone'],
#   'contig_00141.region001.gbk': ['terpene'],
#   'contig_00143.region001.gbk': ['NRPS'],
#   'contig_00147.region001.gbk': ['T3PKS'],
#   'contig_00165.region001.gbk': ['NRPS-like'],
#   'contig_00168.region001.gbk': ['T1PKS'],
#   'contig_00172.region001.gbk': ['NRPS'],
#   'contig_00179.region001.gbk': ['NRPS-like'],
#   'contig_00209.region001.gbk': ['NRPS'],
#   'contig_00226.region001.gbk': ['terpene'],
#   'contig_00260.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00262.region001.gbk': ['terpene'],
#   'contig_00288.region001.gbk': ['RiPP-like'],
#   'contig_00324.region001.gbk': ['terpene']},
#  'Hm77': {'contig_00002.region001.gbk': ['terpene'],
#   'contig_00007.region001.gbk': ['NRPS'],
#   'contig_00008.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00011.region001.gbk': ['RiPP-like'],
#   'contig_00018.region001.gbk': ['NRPS'],
#   'contig_00022.region001.gbk': ['terpene'],
#   'contig_00023.region001.gbk': ['T2PKS'],
#   'contig_00026.region001.gbk': ['terpene'],
#   'contig_00031.region001.gbk': ['T1PKS'],
#   'contig_00033.region001.gbk': ['NRPS'],
#   'contig_00037.region001.gbk': ['terpene'],
#   'contig_00055.region001.gbk': ['melanin'],
#   'contig_00066.region001.gbk': ['T1PKS'],
#   'contig_00071.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00073.region001.gbk': ['NRPS', 'butyrolactone'],
#   'contig_00075.region001.gbk': ['T2PKS', 'terpene'],
#   'contig_00079.region001.gbk': ['siderophore'],
#   'contig_00086.region001.gbk': ['LAP', 'NRPS-like', 'PKS-like'],
#   'contig_00102.region001.gbk': ['PKS-like'],
#   'contig_00112.region001.gbk': ['ectoine'],
#   'contig_00126.region001.gbk': ['lanthipeptide-class-iii',
#    'lanthipeptide-class-ii'],
#   'contig_00131.region001.gbk': ['T2PKS', 'PKS-like', 'T1PKS'],
#   'contig_00143.region001.gbk': ['terpene'],
#   'contig_00160.region001.gbk': ['butyrolactone'],
#   'contig_00193.region001.gbk': ['NRPS'],
#   'contig_00244.region001.gbk': ['T1PKS']},
#  'MBT1': {'contig_00004.region001.gbk': ['indole'],
#   'contig_00005.region001.gbk': ['terpene'],
#   'contig_00006.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00009.region001.gbk': ['siderophore'],
#   'contig_00010.region001.gbk': ['NRPS'],
#   'contig_00013.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00017.region001.gbk': ['terpene'],
#   'contig_00017.region002.gbk': ['hglE-KS'],
#   'contig_00022.region001.gbk': ['terpene'],
#   'contig_00023.region001.gbk': ['terpene'],
#   'contig_00023.region002.gbk': ['indole'],
#   'contig_00025.region001.gbk': ['NRPS'],
#   'contig_00035.region001.gbk': ['ectoine'],
#   'contig_00043.region001.gbk': ['T1PKS'],
#   'contig_00058.region001.gbk': ['T3PKS'],
#   'contig_00062.region001.gbk': ['siderophore'],
#   'contig_00071.region001.gbk': ['lassopeptide'],
#   'contig_00083.region001.gbk': ['NRPS-like', 'T1PKS'],
#   'contig_00095.region001.gbk': ['RiPP-like'],
#   'contig_00096.region001.gbk': ['terpene'],
#   'contig_00109.region001.gbk': ['NRPS'],
#   'contig_00116.region001.gbk': ['T1PKS'],
#   'contig_00154.region001.gbk': ['terpene'],
#   'contig_00162.region001.gbk': ['RiPP-like'],
#   'contig_00164.region001.gbk': ['terpene'],
#   'contig_00179.region001.gbk': ['T2PKS'],
#   'contig_00188.region001.gbk': ['T1PKS'],
#   'contig_00190.region001.gbk': ['T1PKS'],
#   'contig_00214.region001.gbk': ['T2PKS'],
#   'contig_00215.region001.gbk': ['terpene'],
#   'contig_00229.region001.gbk': ['NRPS'],
#   'contig_00236.region001.gbk': ['T1PKS'],
#   'contig_00239.region001.gbk': ['melanin'],
#   'contig_00260.region001.gbk': ['T1PKS'],
#   'contig_00296.region001.gbk': ['NRPS'],
#   'contig_00301.region001.gbk': ['NRPS-like'],
#   'contig_00310.region001.gbk': ['NRPS-like'],
#   'contig_00314.region001.gbk': ['T1PKS'],
#   'contig_00325.region001.gbk': ['hglE-KS'],
#   'contig_00326.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00361.region001.gbk': ['NRPS'],
#   'contig_00364.region001.gbk': ['T1PKS'],
#   'contig_00365.region001.gbk': ['NRPS-like'],
#   'contig_00368.region001.gbk': ['siderophore'],
#   'contig_00379.region001.gbk': ['T1PKS'],
#   'contig_00384.region001.gbk': ['T1PKS'],
#   'contig_00397.region001.gbk': ['T1PKS'],
#   'contig_00400.region001.gbk': ['T1PKS'],
#   'contig_00401.region001.gbk': ['lanthipeptide-class-v'],
#   'contig_00422.region001.gbk': ['T1PKS'],
#   'contig_00423.region001.gbk': ['T1PKS'],
#   'contig_00458.region001.gbk': ['T1PKS'],
#   'contig_00504.region001.gbk': ['butyrolactone'],
#   'contig_00534.region001.gbk': ['butyrolactone']},
#  'MBT10': {'contig_00004.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00005.region001.gbk': ['T2PKS', 'terpene'],
#   'contig_00005.region002.gbk': ['terpene'],
#   'contig_00007.region001.gbk': ['NRPS'],
#   'contig_00007.region002.gbk': ['T1PKS'],
#   'contig_00013.region001.gbk': ['RiPP-like'],
#   'contig_00017.region001.gbk': ['NRPS-like', 'T1PKS'],
#   'contig_00019.region001.gbk': ['NRPS', 'PKS-like'],
#   'contig_00020.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00022.region001.gbk': ['NRPS',
#    'other',
#    'phosphonate',
#    'NRPS-like',
#    'betalactone'],
#   'contig_00025.region001.gbk': ['terpene'],
#   'contig_00026.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00028.region001.gbk': ['lanthipeptide-class-iii', 'NRPS'],
#   'contig_00036.region001.gbk': ['NRPS'],
#   'contig_00038.region001.gbk': ['T1PKS'],
#   'contig_00043.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00062.region001.gbk': ['siderophore'],
#   'contig_00070.region001.gbk': ['NRPS'],
#   'contig_00088.region001.gbk': ['NRPS', 'NRPS-like'],
#   'contig_00103.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00112.region001.gbk': ['terpene'],
#   'contig_00119.region001.gbk': ['terpene'],
#   'contig_00126.region001.gbk': ['NRPS'],
#   'contig_00147.region001.gbk': ['NRPS'],
#   'contig_00149.region001.gbk': ['terpene'],
#   'contig_00161.region001.gbk': ['T1PKS'],
#   'contig_00183.region001.gbk': ['butyrolactone'],
#   'contig_00212.region001.gbk': ['ectoine'],
#   'contig_00214.region001.gbk': ['melanin'],
#   'contig_00216.region001.gbk': ['PKS-like'],
#   'contig_00220.region001.gbk': ['NRPS'],
#   'contig_00223.region001.gbk': ['T1PKS'],
#   'contig_00224.region001.gbk': ['T1PKS', 'hglE-KS'],
#   'contig_00264.region001.gbk': ['T1PKS'],
#   'contig_00277.region001.gbk': ['T1PKS'],
#   'contig_00296.region001.gbk': ['hglE-KS'],
#   'contig_00322.region001.gbk': ['RiPP-like'],
#   'contig_00358.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00377.region001.gbk': ['NRPS']},
#  'MBT12': {'contig_00001.region001.gbk': ['indole'],
#   'contig_00002.region001.gbk': ['T2PKS'],
#   'contig_00002.region002.gbk': ['terpene'],
#   'contig_00004.region001.gbk': ['siderophore'],
#   'contig_00015.region001.gbk': ['terpene'],
#   'contig_00016.region001.gbk': ['indole'],
#   'contig_00016.region002.gbk': ['terpene'],
#   'contig_00018.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00022.region001.gbk': ['NRPS'],
#   'contig_00023.region001.gbk': ['RiPP-like'],
#   'contig_00030.region001.gbk': ['T1PKS'],
#   'contig_00035.region001.gbk': ['lanthipeptide-class-v'],
#   'contig_00041.region001.gbk': ['NRPS'],
#   'contig_00042.region001.gbk': ['terpene'],
#   'contig_00042.region002.gbk': ['hglE-KS'],
#   'contig_00058.region001.gbk': ['melanin'],
#   'contig_00059.region001.gbk': ['siderophore'],
#   'contig_00067.region001.gbk': ['terpene'],
#   'contig_00072.region001.gbk': ['T3PKS'],
#   'contig_00075.region001.gbk': ['T1PKS'],
#   'contig_00112.region001.gbk': ['RiPP-like'],
#   'contig_00114.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00116.region001.gbk': ['terpene'],
#   'contig_00118.region001.gbk': ['NRPS'],
#   'contig_00129.region001.gbk': ['T1PKS'],
#   'contig_00132.region001.gbk': ['NRPS'],
#   'contig_00144.region001.gbk': ['ectoine'],
#   'contig_00158.region001.gbk': ['NRPS-like', 'T1PKS'],
#   'contig_00169.region001.gbk': ['T2PKS'],
#   'contig_00174.region001.gbk': ['lassopeptide'],
#   'contig_00191.region001.gbk': ['T1PKS'],
#   'contig_00196.region001.gbk': ['terpene'],
#   'contig_00201.region001.gbk': ['T2PKS'],
#   'contig_00256.region001.gbk': ['siderophore'],
#   'contig_00264.region001.gbk': ['NRPS-like', 'T1PKS'],
#   'contig_00268.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00271.region001.gbk': ['T1PKS'],
#   'contig_00275.region001.gbk': ['hglE-KS'],
#   'contig_00279.region001.gbk': ['NRPS'],
#   'contig_00285.region001.gbk': ['T1PKS'],
#   'contig_00287.region001.gbk': ['T1PKS'],
#   'contig_00288.region001.gbk': ['NRPS-like'],
#   'contig_00307.region001.gbk': ['T1PKS'],
#   'contig_00309.region001.gbk': ['T1PKS'],
#   'contig_00317.region001.gbk': ['T1PKS'],
#   'contig_00364.region001.gbk': ['butyrolactone']},
#  'MBT13': {'contig_00002.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00002.region002.gbk': ['butyrolactone'],
#   'contig_00005.region001.gbk': ['RRE-containing'],
#   'contig_00015.region001.gbk': ['LAP', 'thiopeptide'],
#   'contig_00019.region001.gbk': ['terpene'],
#   'contig_00024.region001.gbk': ['T3PKS'],
#   'contig_00026.region001.gbk': ['T1PKS'],
#   'contig_00039.region001.gbk': ['T1PKS'],
#   'contig_00042.region001.gbk': ['terpene'],
#   'contig_00062.region001.gbk': ['NRPS'],
#   'contig_00070.region001.gbk': ['T1PKS'],
#   'contig_00072.region001.gbk': ['NRPS'],
#   'contig_00074.region001.gbk': ['siderophore'],
#   'contig_00076.region001.gbk': ['NRPS'],
#   'contig_00079.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00085.region001.gbk': ['T1PKS'],
#   'contig_00116.region001.gbk': ['terpene'],
#   'contig_00119.region001.gbk': ['NRPS'],
#   'contig_00123.region001.gbk': ['NRPS'],
#   'contig_00124.region001.gbk': ['terpene'],
#   'contig_00130.region001.gbk': ['NRPS'],
#   'contig_00142.region001.gbk': ['NRPS'],
#   'contig_00157.region001.gbk': ['butyrolactone'],
#   'contig_00158.region001.gbk': ['NRPS-like'],
#   'contig_00163.region001.gbk': ['melanin'],
#   'contig_00170.region001.gbk': ['NRPS'],
#   'contig_00184.region001.gbk': ['terpene'],
#   'contig_00207.region001.gbk': ['melanin'],
#   'contig_00210.region001.gbk': ['T2PKS'],
#   'contig_00250.region001.gbk': ['RiPP-like'],
#   'contig_00254.region001.gbk': ['T1PKS'],
#   'contig_00265.region001.gbk': ['T2PKS'],
#   'contig_00282.region001.gbk': ['NAPAA'],
#   'contig_00295.region001.gbk': ['NRPS'],
#   'contig_00315.region001.gbk': ['terpene'],
#   'contig_00335.region001.gbk': ['terpene'],
#   'contig_00337.region001.gbk': ['butyrolactone'],
#   'contig_00352.region001.gbk': ['NRPS-like'],
#   'contig_00365.region001.gbk': ['NRPS-like'],
#   'contig_00390.region001.gbk': ['ectoine'],
#   'contig_00395.region001.gbk': ['NRPS'],
#   'contig_00398.region001.gbk': ['other'],
#   'contig_00426.region001.gbk': ['T1PKS'],
#   'contig_00428.region001.gbk': ['T1PKS'],
#   'contig_00451.region001.gbk': ['NRPS']},
#  'MBT14': {'contig_00001.region001.gbk': ['butyrolactone'],
#   'contig_00005.region001.gbk': ['terpene'],
#   'contig_00008.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00008.region002.gbk': ['terpene'],
#   'contig_00017.region001.gbk': ['RiPP-like'],
#   'contig_00018.region001.gbk': ['melanin'],
#   'contig_00021.region001.gbk': ['NRPS-like'],
#   'contig_00022.region001.gbk': ['terpene'],
#   'contig_00024.region001.gbk': ['NRPS-like', 'betalactone', 'NRPS'],
#   'contig_00025.region001.gbk': ['terpene'],
#   'contig_00026.region001.gbk': ['NRPS', 'betalactone', 'NRPS-like'],
#   'contig_00035.region001.gbk': ['RiPP-like'],
#   'contig_00043.region001.gbk': ['siderophore'],
#   'contig_00046.region001.gbk': ['siderophore'],
#   'contig_00049.region001.gbk': ['NRPS'],
#   'contig_00055.region001.gbk': ['ectoine'],
#   'contig_00058.region001.gbk': ['terpene'],
#   'contig_00059.region001.gbk': ['blactam'],
#   'contig_00068.region001.gbk': ['terpene'],
#   'contig_00073.region001.gbk': ['NRPS'],
#   'contig_00079.region001.gbk': ['T3PKS'],
#   'contig_00096.region001.gbk': ['terpene'],
#   'contig_00109.region001.gbk': ['T2PKS'],
#   'contig_00110.region001.gbk': ['NAPAA'],
#   'contig_00111.region001.gbk': ['NRPS'],
#   'contig_00115.region001.gbk': ['NRPS', 'NRPS-like'],
#   'contig_00123.region001.gbk': ['butyrolactone'],
#   'contig_00147.region001.gbk': ['butyrolactone'],
#   'contig_00156.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00164.region001.gbk': ['T2PKS'],
#   'contig_00194.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00211.region001.gbk': ['butyrolactone'],
#   'contig_00254.region001.gbk': ['RiPP-like'],
#   'contig_00255.region001.gbk': ['NRPS'],
#   'contig_00268.region001.gbk': ['NRPS-like']},
#  'MBT21': {'contig_00002.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00004.region001.gbk': ['terpene'],
#   'contig_00006.region001.gbk': ['NRPS'],
#   'contig_00007.region001.gbk': ['NAPAA'],
#   'contig_00009.region001.gbk': ['terpene'],
#   'contig_00016.region001.gbk': ['lanthipeptide-class-iii', 'T2PKS'],
#   'contig_00021.region001.gbk': ['terpene'],
#   'contig_00024.region001.gbk': ['T1PKS'],
#   'contig_00027.region001.gbk': ['terpene'],
#   'contig_00035.region001.gbk': ['other'],
#   'contig_00046.region001.gbk': ['siderophore'],
#   'contig_00050.region001.gbk': ['lassopeptide'],
#   'contig_00056.region001.gbk': ['siderophore'],
#   'contig_00060.region001.gbk': ['NRPS'],
#   'contig_00081.region001.gbk': ['NRPS', 'terpene'],
#   'contig_00085.region001.gbk': ['NRPS'],
#   'contig_00095.region001.gbk': ['NRPS'],
#   'contig_00098.region001.gbk': ['ectoine'],
#   'contig_00121.region001.gbk': ['NRPS'],
#   'contig_00122.region001.gbk': ['butyrolactone'],
#   'contig_00125.region001.gbk': ['melanin'],
#   'contig_00139.region001.gbk': ['melanin'],
#   'contig_00142.region001.gbk': ['RRE-containing'],
#   'contig_00152.region001.gbk': ['NRPS-like', 'T1PKS'],
#   'contig_00153.region001.gbk': ['terpene'],
#   'contig_00174.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00221.region001.gbk': ['RiPP-like'],
#   'contig_00245.region001.gbk': ['terpene'],
#   'contig_00247.region001.gbk': ['CDPS'],
#   'contig_00261.region001.gbk': ['cyanobactin'],
#   'contig_00263.region001.gbk': ['siderophore'],
#   'contig_00305.region001.gbk': ['RiPP-like'],
#   'contig_00333.region001.gbk': ['NRPS'],
#   'contig_00336.region001.gbk': ['butyrolactone'],
#   'contig_00338.region001.gbk': ['NRPS'],
#   'contig_00339.region001.gbk': ['T1PKS'],
#   'contig_00392.region001.gbk': ['NRPS'],
#   'contig_00401.region001.gbk': ['LAP']},
#  'MBT27': {'contig_00001.region001.gbk': ['other'],
#   'contig_00002.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00002.region002.gbk': ['thiopeptide', 'LAP', 'T3PKS'],
#   'contig_00002.region003.gbk': ['NRPS-like', 'betalactone', 'NRPS'],
#   'contig_00005.region001.gbk': ['indole'],
#   'contig_00006.region001.gbk': ['RiPP-like'],
#   'contig_00007.region001.gbk': ['RiPP-like', 'NRPS'],
#   'contig_00009.region001.gbk': ['NRPS'],
#   'contig_00014.region001.gbk': ['terpene'],
#   'contig_00014.region002.gbk': ['RiPP-like'],
#   'contig_00017.region001.gbk': ['NRPS', 'NRPS-like'],
#   'contig_00022.region001.gbk': ['lanthipeptide-class-iv'],
#   'contig_00026.region001.gbk': ['T1PKS'],
#   'contig_00027.region001.gbk': ['terpene'],
#   'contig_00030.region001.gbk': ['NRPS'],
#   'contig_00038.region001.gbk': ['other'],
#   'contig_00045.region001.gbk': ['NRPS'],
#   'contig_00051.region001.gbk': ['terpene'],
#   'contig_00054.region001.gbk': ['T1PKS'],
#   'contig_00055.region001.gbk': ['T3PKS'],
#   'contig_00078.region001.gbk': ['terpene'],
#   'contig_00079.region001.gbk': ['NRPS'],
#   'contig_00083.region001.gbk': ['NRPS'],
#   'contig_00086.region001.gbk': ['RiPP-like'],
#   'contig_00091.region001.gbk': ['ectoine'],
#   'contig_00094.region001.gbk': ['NRPS', 'oligosaccharide'],
#   'contig_00104.region001.gbk': ['CDPS'],
#   'contig_00110.region001.gbk': ['NRPS-like'],
#   'contig_00120.region001.gbk': ['T2PKS', 'RRE-containing'],
#   'contig_00123.region001.gbk': ['PKS-like', 'amglyccycl', 'butyrolactone'],
#   'contig_00124.region001.gbk': ['butyrolactone'],
#   'contig_00141.region001.gbk': ['melanin'],
#   'contig_00144.region001.gbk': ['siderophore'],
#   'contig_00146.region001.gbk': ['NRPS'],
#   'contig_00152.region001.gbk': ['NRPS-like', 'lanthipeptide-class-iv'],
#   'contig_00154.region001.gbk': ['siderophore'],
#   'contig_00191.region001.gbk': ['NRPS'],
#   'contig_00207.region001.gbk': ['NAPAA'],
#   'contig_00223.region001.gbk': ['T3PKS'],
#   'contig_00225.region001.gbk': ['NRPS'],
#   'contig_00226.region001.gbk': ['NRPS'],
#   'contig_00239.region001.gbk': ['terpene'],
#   'contig_00290.region001.gbk': ['terpene'],
#   'contig_00293.region001.gbk': ['other'],
#   'contig_00299.region001.gbk': ['NRPS'],
#   'contig_00338.region001.gbk': ['NRPS-like'],
#   'contig_00342.region001.gbk': ['NRPS'],
#   'contig_00344.region001.gbk': ['NRPS'],
#   'contig_00376.region001.gbk': ['NRPS'],
#   'contig_00402.region001.gbk': ['NRPS'],
#   'contig_00414.region001.gbk': ['NRPS'],
#   'contig_00435.region001.gbk': ['NRPS']},
#  'MBT3': {'contig_00001.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00003.region001.gbk': ['siderophore'],
#   'contig_00005.region001.gbk': ['indole'],
#   'contig_00023.region001.gbk': ['hglE-KS'],
#   'contig_00023.region002.gbk': ['terpene'],
#   'contig_00027.region001.gbk': ['ectoine'],
#   'contig_00029.region001.gbk': ['terpene'],
#   'contig_00030.region001.gbk': ['NRPS'],
#   'contig_00034.region001.gbk': ['terpene'],
#   'contig_00035.region001.gbk': ['T2PKS'],
#   'contig_00048.region001.gbk': ['terpene'],
#   'contig_00054.region001.gbk': ['indole'],
#   'contig_00055.region001.gbk': ['T3PKS'],
#   'contig_00059.region001.gbk': ['terpene'],
#   'contig_00066.region001.gbk': ['NRPS'],
#   'contig_00071.region001.gbk': ['NRPS-like', 'T1PKS'],
#   'contig_00072.region001.gbk': ['RiPP-like'],
#   'contig_00079.region001.gbk': ['siderophore'],
#   'contig_00084.region001.gbk': ['PKS-like', 'furan'],
#   'contig_00095.region001.gbk': ['lanthipeptide-class-v'],
#   'contig_00099.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00109.region001.gbk': ['hglE-KS', 'T1PKS'],
#   'contig_00116.region001.gbk': ['T1PKS'],
#   'contig_00130.region001.gbk': ['terpene'],
#   'contig_00131.region001.gbk': ['siderophore'],
#   'contig_00155.region001.gbk': ['NRPS-like'],
#   'contig_00158.region001.gbk': ['terpene'],
#   'contig_00170.region001.gbk': ['T1PKS'],
#   'contig_00173.region001.gbk': ['T1PKS'],
#   'contig_00177.region001.gbk': ['NRPS'],
#   'contig_00183.region001.gbk': ['T1PKS'],
#   'contig_00186.region001.gbk': ['T1PKS'],
#   'contig_00195.region001.gbk': ['terpene'],
#   'contig_00196.region001.gbk': ['T1PKS'],
#   'contig_00230.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00250.region001.gbk': ['T2PKS'],
#   'contig_00252.region001.gbk': ['T2PKS'],
#   'contig_00257.region001.gbk': ['melanin'],
#   'contig_00262.region001.gbk': ['T1PKS'],
#   'contig_00265.region001.gbk': ['T1PKS'],
#   'contig_00275.region001.gbk': ['T2PKS'],
#   'contig_00282.region001.gbk': ['T1PKS'],
#   'contig_00283.region001.gbk': ['NRPS'],
#   'contig_00286.region001.gbk': ['NRPS'],
#   'contig_00290.region001.gbk': ['T1PKS'],
#   'contig_00294.region001.gbk': ['T1PKS'],
#   'contig_00315.region001.gbk': ['T1PKS'],
#   'contig_00344.region001.gbk': ['NRPS-like'],
#   'contig_00349.region001.gbk': ['T1PKS'],
#   'contig_00372.region001.gbk': ['NRPS'],
#   'contig_00379.region001.gbk': ['T1PKS'],
#   'contig_00441.region001.gbk': ['butyrolactone'],
#   'contig_00473.region001.gbk': ['RiPP-like']},
#  'MBT34': {'contig_00001.region001.gbk': ['T1PKS', 'other'],
#   'contig_00003.region001.gbk': ['terpene'],
#   'contig_00003.region002.gbk': ['NRPS'],
#   'contig_00005.region001.gbk': ['arylpolyene'],
#   'contig_00006.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00006.region002.gbk': ['siderophore'],
#   'contig_00007.region001.gbk': ['T1PKS'],
#   'contig_00009.region001.gbk': ['NRPS'],
#   'contig_00012.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00013.region001.gbk': ['T2PKS', 'NRPS', 'oligosaccharide'],
#   'contig_00018.region001.gbk': ['thiopeptide', 'LAP'],
#   'contig_00018.region002.gbk': ['T1PKS', 'NRPS-like'],
#   'contig_00023.region001.gbk': ['NRPS'],
#   'contig_00027.region001.gbk': ['terpene'],
#   'contig_00028.region001.gbk': ['T3PKS'],
#   'contig_00029.region001.gbk': ['ectoine'],
#   'contig_00031.region001.gbk': ['RiPP-like'],
#   'contig_00033.region001.gbk': ['NRPS', 'T3PKS'],
#   'contig_00035.region001.gbk': ['melanin'],
#   'contig_00037.region001.gbk': ['NRPS', 'arylpolyene', 'ladderane'],
#   'contig_00049.region001.gbk': ['linaridin'],
#   'contig_00055.region001.gbk': ['NRPS-like', 'NRPS'],
#   'contig_00060.region001.gbk': ['terpene'],
#   'contig_00074.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00079.region001.gbk': ['terpene'],
#   'contig_00085.region001.gbk': ['terpene'],
#   'contig_00090.region001.gbk': ['butyrolactone'],
#   'contig_00091.region001.gbk': ['melanin'],
#   'contig_00092.region001.gbk': ['T1PKS', 'NRPS-like'],
#   'contig_00096.region001.gbk': ['transAT-PKS'],
#   'contig_00107.region001.gbk': ['NRPS'],
#   'contig_00112.region001.gbk': ['T3PKS'],
#   'contig_00119.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00124.region001.gbk': ['butyrolactone', 'ectoine'],
#   'contig_00141.region001.gbk': ['terpene'],
#   'contig_00143.region001.gbk': ['NRPS'],
#   'contig_00146.region001.gbk': ['NRPS-like', 'lanthipeptide-class-iv'],
#   'contig_00154.region001.gbk': ['RiPP-like'],
#   'contig_00207.region001.gbk': ['NRPS'],
#   'contig_00235.region001.gbk': ['NRPS'],
#   'contig_00260.region001.gbk': ['NRPS'],
#   'contig_00279.region001.gbk': ['NRPS'],
#   'contig_00284.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00285.region001.gbk': ['NRPS'],
#   'contig_00303.region001.gbk': ['NRPS'],
#   'contig_00325.region001.gbk': ['NRPS'],
#   'contig_00326.region001.gbk': ['siderophore'],
#   'contig_00332.region001.gbk': ['transAT-PKS-like'],
#   'contig_00366.region001.gbk': ['NRPS'],
#   'contig_00374.region001.gbk': ['siderophore'],
#   'contig_00378.region001.gbk': ['NRPS']},
#  'MBT37': {'contig_00001.region001.gbk': ['terpene'],
#   'contig_00003.region001.gbk': ['terpene'],
#   'contig_00005.region001.gbk': ['T3PKS'],
#   'contig_00005.region002.gbk': ['melanin'],
#   'contig_00010.region001.gbk': ['T1PKS', 'NRPS'],
#   'contig_00013.region001.gbk': ['NRPS'],
#   'contig_00014.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00018.region001.gbk': ['NRPS'],
#   'contig_00023.region001.gbk': ['other', 'NRPS', 'T1PKS'],
#   'contig_00034.region001.gbk': ['siderophore'],
#   'contig_00049.region001.gbk': ['lanthipeptide-class-iv'],
#   'contig_00051.region001.gbk': ['NRPS', 'terpene'],
#   'contig_00062.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00067.region001.gbk': ['NRPS-like'],
#   'contig_00072.region001.gbk': ['T3PKS'],
#   'contig_00090.region001.gbk': ['lassopeptide'],
#   'contig_00091.region001.gbk': ['NRPS'],
#   'contig_00093.region001.gbk': ['RiPP-like'],
#   'contig_00132.region001.gbk': ['T1PKS'],
#   'contig_00143.region001.gbk': ['NRPS'],
#   'contig_00148.region001.gbk': ['siderophore'],
#   'contig_00153.region001.gbk': ['T1PKS', 'NRPS'],
#   'contig_00161.region001.gbk': ['ectoine'],
#   'contig_00165.region001.gbk': ['ectoine'],
#   'contig_00174.region001.gbk': ['LAP', 'thiopeptide'],
#   'contig_00182.region001.gbk': ['terpene'],
#   'contig_00188.region001.gbk': ['RiPP-like'],
#   'contig_00193.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00198.region001.gbk': ['terpene'],
#   'contig_00215.region001.gbk': ['butyrolactone'],
#   'contig_00221.region001.gbk': ['NRPS-like', 'T1PKS'],
#   'contig_00222.region001.gbk': ['terpene'],
#   'contig_00231.region001.gbk': ['butyrolactone'],
#   'contig_00265.region001.gbk': ['terpene']},
#  'MBT38': {'contig_00004.region001.gbk': ['siderophore'],
#   'contig_00010.region001.gbk': ['terpene'],
#   'contig_00017.region001.gbk': ['terpene'],
#   'contig_00017.region002.gbk': ['T2PKS'],
#   'contig_00018.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00023.region001.gbk': ['terpene'],
#   'contig_00023.region002.gbk': ['hglE-KS'],
#   'contig_00029.region001.gbk': ['indole'],
#   'contig_00034.region001.gbk': ['T1PKS', 'NRPS-like', 'NRPS'],
#   'contig_00035.region001.gbk': ['T1PKS'],
#   'contig_00045.region001.gbk': ['T3PKS'],
#   'contig_00047.region001.gbk': ['NRPS'],
#   'contig_00054.region001.gbk': ['lanthipeptide-class-v'],
#   'contig_00058.region001.gbk': ['NRPS'],
#   'contig_00066.region001.gbk': ['indole'],
#   'contig_00066.region002.gbk': ['terpene'],
#   'contig_00078.region001.gbk': ['T1PKS'],
#   'contig_00088.region001.gbk': ['terpene'],
#   'contig_00095.region001.gbk': ['terpene'],
#   'contig_00112.region001.gbk': ['RiPP-like'],
#   'contig_00115.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00118.region001.gbk': ['ectoine'],
#   'contig_00127.region001.gbk': ['NRPS'],
#   'contig_00129.region001.gbk': ['lassopeptide'],
#   'contig_00132.region001.gbk': ['siderophore'],
#   'contig_00138.region001.gbk': ['terpene'],
#   'contig_00140.region001.gbk': ['NRPS-like', 'T1PKS'],
#   'contig_00149.region001.gbk': ['T1PKS'],
#   'contig_00160.region001.gbk': ['NRPS-like'],
#   'contig_00178.region001.gbk': ['melanin'],
#   'contig_00189.region001.gbk': ['T1PKS'],
#   'contig_00191.region001.gbk': ['RiPP-like'],
#   'contig_00200.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00201.region001.gbk': ['T2PKS'],
#   'contig_00214.region001.gbk': ['T2PKS'],
#   'contig_00215.region001.gbk': ['T1PKS'],
#   'contig_00253.region001.gbk': ['T1PKS'],
#   'contig_00269.region001.gbk': ['T1PKS'],
#   'contig_00278.region001.gbk': ['NRPS'],
#   'contig_00283.region001.gbk': ['T1PKS'],
#   'contig_00288.region001.gbk': ['T1PKS'],
#   'contig_00297.region001.gbk': ['T1PKS'],
#   'contig_00302.region001.gbk': ['T1PKS'],
#   'contig_00306.region001.gbk': ['T1PKS'],
#   'contig_00307.region001.gbk': ['T1PKS'],
#   'contig_00308.region001.gbk': ['NRPS-like'],
#   'contig_00377.region001.gbk': ['T1PKS']},
#  'MBT39': {'contig_00001.region001.gbk': ['linaridin'],
#   'contig_00001.region002.gbk': ['butyrolactone'],
#   'contig_00002.region001.gbk': ['hglE-KS', 'T1PKS'],
#   'contig_00003.region001.gbk': ['siderophore'],
#   'contig_00004.region001.gbk': ['RiPP-like'],
#   'contig_00007.region001.gbk': ['NRPS'],
#   'contig_00008.region001.gbk': ['NRPS', 'NRPS-like'],
#   'contig_00009.region001.gbk': ['NRPS'],
#   'contig_00012.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00013.region001.gbk': ['NRPS'],
#   'contig_00016.region001.gbk': ['hglE-KS'],
#   'contig_00016.region002.gbk': ['terpene'],
#   'contig_00017.region001.gbk': ['RiPP-like'],
#   'contig_00018.region001.gbk': ['nucleoside'],
#   'contig_00030.region001.gbk': ['siderophore'],
#   'contig_00031.region001.gbk': ['T1PKS'],
#   'contig_00032.region001.gbk': ['terpene'],
#   'contig_00032.region002.gbk': ['indole'],
#   'contig_00033.region001.gbk': ['terpene'],
#   'contig_00036.region001.gbk': ['terpene'],
#   'contig_00037.region001.gbk': ['NRPS-like'],
#   'contig_00044.region001.gbk': ['NRPS'],
#   'contig_00046.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00050.region001.gbk': ['NAPAA'],
#   'contig_00051.region001.gbk': ['NRPS'],
#   'contig_00065.region001.gbk': ['NRPS-like'],
#   'contig_00066.region001.gbk': ['terpene'],
#   'contig_00072.region001.gbk': ['butyrolactone'],
#   'contig_00074.region001.gbk': ['terpene'],
#   'contig_00079.region001.gbk': ['T1PKS'],
#   'contig_00085.region001.gbk': ['melanin', 'T3PKS'],
#   'contig_00087.region001.gbk': ['T1PKS'],
#   'contig_00088.region001.gbk': ['T1PKS'],
#   'contig_00091.region001.gbk': ['T3PKS'],
#   'contig_00105.region001.gbk': ['indole'],
#   'contig_00107.region001.gbk': ['ectoine'],
#   'contig_00125.region001.gbk': ['siderophore'],
#   'contig_00127.region001.gbk': ['linaridin'],
#   'contig_00129.region001.gbk': ['NRPS'],
#   'contig_00141.region001.gbk': ['terpene'],
#   'contig_00142.region001.gbk': ['lanthipeptide-class-v'],
#   'contig_00151.region001.gbk': ['T3PKS', 'NRPS'],
#   'contig_00160.region001.gbk': ['terpene'],
#   'contig_00171.region001.gbk': ['NRPS'],
#   'contig_00174.region001.gbk': ['terpene'],
#   'contig_00178.region001.gbk': ['T1PKS'],
#   'contig_00188.region001.gbk': ['RiPP-like'],
#   'contig_00194.region001.gbk': ['linaridin'],
#   'contig_00199.region001.gbk': ['T3PKS'],
#   'contig_00203.region001.gbk': ['RRE-containing'],
#   'contig_00213.region001.gbk': ['RRE-containing'],
#   'contig_00217.region001.gbk': ['T1PKS'],
#   'contig_00222.region001.gbk': ['NRPS-like'],
#   'contig_00231.region001.gbk': ['T1PKS'],
#   'contig_00234.region001.gbk': ['NRPS'],
#   'contig_00235.region001.gbk': ['thiopeptide'],
#   'contig_00250.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00255.region001.gbk': ['T1PKS'],
#   'contig_00291.region001.gbk': ['ectoine'],
#   'contig_00293.region001.gbk': ['T1PKS'],
#   'contig_00310.region001.gbk': ['RiPP-like'],
#   'contig_00322.region001.gbk': ['lassopeptide'],
#   'contig_00325.region001.gbk': ['terpene'],
#   'contig_00331.region001.gbk': ['PKS-like', 'T1PKS'],
#   'contig_00354.region001.gbk': ['RRE-containing'],
#   'contig_00370.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00382.region001.gbk': ['T1PKS'],
#   'contig_00384.region001.gbk': ['T2PKS'],
#   'contig_00390.region001.gbk': ['NRPS-like', 'T1PKS'],
#   'contig_00408.region001.gbk': ['CDPS', 'terpene'],
#   'contig_00419.region001.gbk': ['T1PKS'],
#   'contig_00434.region001.gbk': ['T1PKS'],
#   'contig_00454.region001.gbk': ['RiPP-like'],
#   'contig_00463.region001.gbk': ['T1PKS'],
#   'contig_00473.region001.gbk': ['ectoine'],
#   'contig_00483.region001.gbk': ['T2PKS'],
#   'contig_00492.region001.gbk': ['NRPS'],
#   'contig_00521.region001.gbk': ['T1PKS'],
#   'contig_00522.region001.gbk': ['thiopeptide'],
#   'contig_00529.region001.gbk': ['terpene'],
#   'contig_00537.region001.gbk': ['NRPS'],
#   'contig_00549.region001.gbk': ['melanin'],
#   'contig_00565.region001.gbk': ['T1PKS'],
#   'contig_00570.region001.gbk': ['RiPP-like'],
#   'contig_00573.region001.gbk': ['T1PKS'],
#   'contig_00574.region001.gbk': ['NRPS'],
#   'contig_00589.region001.gbk': ['NRPS'],
#   'contig_00626.region001.gbk': ['NRPS-like'],
#   'contig_00643.region001.gbk': ['T1PKS'],
#   'contig_00672.region001.gbk': ['NRPS'],
#   'contig_00694.region001.gbk': ['hglE-KS'],
#   'contig_00701.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00769.region001.gbk': ['NRPS'],
#   'contig_00772.region001.gbk': ['NRPS-like'],
#   'contig_00780.region001.gbk': ['T1PKS'],
#   'contig_00819.region001.gbk': ['T1PKS'],
#   'contig_00822.region001.gbk': ['T1PKS'],
#   'contig_00829.region001.gbk': ['NRPS'],
#   'contig_00833.region001.gbk': ['NRPS-like'],
#   'contig_00860.region001.gbk': ['terpene'],
#   'contig_00861.region001.gbk': ['NRPS'],
#   'contig_00903.region001.gbk': ['T1PKS'],
#   'contig_00911.region001.gbk': ['T1PKS'],
#   'contig_00944.region001.gbk': ['siderophore'],
#   'contig_00947.region001.gbk': ['NRPS'],
#   'contig_00959.region001.gbk': ['NRPS'],
#   'contig_00966.region001.gbk': ['NRPS'],
#   'contig_00971.region001.gbk': ['NRPS'],
#   'contig_01073.region001.gbk': ['butyrolactone'],
#   'contig_01130.region001.gbk': ['T1PKS']},
#  'MBT44': {'contig_00002.region001.gbk': ['RiPP-like'],
#   'contig_00002.region002.gbk': ['NRPS', 'T1PKS'],
#   'contig_00005.region001.gbk': ['PKS-like',
#    'NRPS',
#    'betalactone',
#    'NRPS-like'],
#   'contig_00007.region001.gbk': ['T3PKS'],
#   'contig_00008.region001.gbk': ['T3PKS'],
#   'contig_00009.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00011.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00014.region001.gbk': ['thioamide-NRP', 'T1PKS', 'PKS-like'],
#   'contig_00015.region001.gbk': ['NRPS'],
#   'contig_00016.region001.gbk': ['terpene'],
#   'contig_00025.region001.gbk': ['terpene'],
#   'contig_00026.region001.gbk': ['siderophore'],
#   'contig_00027.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00028.region001.gbk': ['T1PKS'],
#   'contig_00030.region001.gbk': ['RRE-containing'],
#   'contig_00032.region001.gbk': ['terpene'],
#   'contig_00035.region001.gbk': ['lanthipeptide-class-iii',
#    'lanthipeptide-class-ii'],
#   'contig_00036.region001.gbk': ['T2PKS'],
#   'contig_00041.region001.gbk': ['ectoine'],
#   'contig_00044.region001.gbk': ['RRE-containing'],
#   'contig_00050.region001.gbk': ['butyrolactone'],
#   'contig_00053.region001.gbk': ['NRPS'],
#   'contig_00068.region001.gbk': ['hglE-KS'],
#   'contig_00071.region001.gbk': ['NRPS'],
#   'contig_00082.region001.gbk': ['NRPS'],
#   'contig_00090.region001.gbk': ['NRPS'],
#   'contig_00091.region001.gbk': ['NRPS'],
#   'contig_00099.region001.gbk': ['other'],
#   'contig_00106.region001.gbk': ['ectoine'],
#   'contig_00108.region001.gbk': ['RiPP-like'],
#   'contig_00113.region001.gbk': ['ladderane', 'arylpolyene'],
#   'contig_00133.region001.gbk': ['ectoine', 'butyrolactone'],
#   'contig_00136.region001.gbk': ['melanin'],
#   'contig_00162.region001.gbk': ['siderophore'],
#   'contig_00164.region001.gbk': ['NRPS'],
#   'contig_00178.region001.gbk': ['terpene'],
#   'contig_00186.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00190.region001.gbk': ['lanthipeptide-class-iv'],
#   'contig_00202.region001.gbk': ['NRPS'],
#   'contig_00204.region001.gbk': ['NRPS'],
#   'contig_00209.region001.gbk': ['phenazine'],
#   'contig_00213.region001.gbk': ['T2PKS', 'butyrolactone'],
#   'contig_00219.region001.gbk': ['NRPS'],
#   'contig_00270.region001.gbk': ['T3PKS'],
#   'contig_00273.region001.gbk': ['NRPS-like'],
#   'contig_00281.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00286.region001.gbk': ['NRPS'],
#   'contig_00300.region001.gbk': ['NRPS'],
#   'contig_00320.region001.gbk': ['NRPS'],
#   'contig_00330.region001.gbk': ['NRPS'],
#   'contig_00346.region001.gbk': ['lassopeptide'],
#   'contig_00350.region001.gbk': ['NRPS']},
#  'MBT47': {'contig_00001.region001.gbk': ['butyrolactone'],
#   'contig_00007.region001.gbk': ['melanin'],
#   'contig_00009.region001.gbk': ['PKS-like'],
#   'contig_00010.region001.gbk': ['lassopeptide'],
#   'contig_00011.region001.gbk': ['RiPP-like'],
#   'contig_00021.region001.gbk': ['T3PKS'],
#   'contig_00024.region001.gbk': ['NRPS-like'],
#   'contig_00030.region001.gbk': ['NRPS-like'],
#   'contig_00031.region001.gbk': ['NRPS'],
#   'contig_00035.region001.gbk': ['terpene'],
#   'contig_00047.region001.gbk': ['NRPS-like', 'NRPS'],
#   'contig_00058.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00060.region001.gbk': ['NRPS'],
#   'contig_00064.region001.gbk': ['linaridin'],
#   'contig_00071.region001.gbk': ['terpene'],
#   'contig_00074.region001.gbk': ['NRPS'],
#   'contig_00092.region001.gbk': ['T2PKS'],
#   'contig_00094.region001.gbk': ['other'],
#   'contig_00104.region001.gbk': ['T2PKS', 'PKS-like', 'RRE-containing'],
#   'contig_00107.region001.gbk': ['RiPP-like'],
#   'contig_00113.region001.gbk': ['NRPS'],
#   'contig_00114.region001.gbk': ['NRPS'],
# ...
#   'contig_00003.region001.gbk': ['guanidinotides', 'arylpolyene', 'NRPS-like'],
#   'contig_00011.region001.gbk': ['terpene'],
#   'contig_00017.region001.gbk': ['indole'],
#   'contig_00018.region001.gbk': ['terpene'],
#   'contig_00019.region001.gbk': ['NRPS',
#    'lanthipeptide-class-i',
#    'lanthipeptide-class-ii'],
#   'contig_00024.region001.gbk': ['NAPAA'],
#   'contig_00041.region001.gbk': ['NRPS-like'],
#   'contig_00051.region001.gbk': ['siderophore'],
#   'contig_00061.region001.gbk': ['other', 'T1PKS'],
#   'contig_00066.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00068.region001.gbk': ['RiPP-like'],
#   'contig_00077.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00079.region001.gbk': ['hglE-KS', 'T1PKS'],
#   'contig_00081.region001.gbk': ['terpene'],
#   'contig_00095.region001.gbk': ['RiPP-like'],
#   'contig_00101.region001.gbk': ['melanin', 'terpene'],
#   'contig_00103.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00118.region001.gbk': ['T1PKS'],
#   'contig_00132.region001.gbk': ['terpene'],
#   'contig_00133.region001.gbk': ['T1PKS'],
#   'contig_00139.region001.gbk': ['lanthipeptide-class-iv'],
#   'contig_00159.region001.gbk': ['terpene'],
#   'contig_00166.region001.gbk': ['butyrolactone'],
#   'contig_00174.region001.gbk': ['T2PKS'],
#   'contig_00186.region001.gbk': ['T1PKS'],
#   'contig_00189.region001.gbk': ['nucleoside'],
#   'contig_00191.region001.gbk': ['NRPS'],
#   'contig_00205.region001.gbk': ['other', 'terpene'],
#   'contig_00208.region001.gbk': ['NRPS'],
#   'contig_00220.region001.gbk': ['NRPS', 'siderophore'],
#   'contig_00239.region001.gbk': ['PKS-like'],
#   'contig_00247.region001.gbk': ['T3PKS'],
#   'contig_00279.region001.gbk': ['T3PKS'],
#   'contig_00292.region001.gbk': ['siderophore'],
#   'contig_00293.region001.gbk': ['T3PKS'],
#   'contig_00308.region001.gbk': ['T1PKS'],
#   'contig_00311.region001.gbk': ['NRPS'],
#   'contig_00319.region001.gbk': ['NRPS-like'],
#   'contig_00325.region001.gbk': ['nucleoside'],
#   'contig_00346.region001.gbk': ['T1PKS'],
#   'contig_00355.region001.gbk': ['ectoine'],
#   'contig_00361.region001.gbk': ['T1PKS'],
#   'contig_00363.region001.gbk': ['siderophore'],
#   'contig_00376.region001.gbk': ['melanin'],
#   'contig_00394.region001.gbk': ['terpene', 'other'],
#   'contig_00455.region001.gbk': ['NRPS'],
#   'contig_00515.region001.gbk': ['T1PKS'],
#   'contig_00522.region001.gbk': ['T1PKS']},
#  'MBT64': {'contig_00001.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00004.region001.gbk': ['lanthipeptide-class-i'],
#   'contig_00005.region001.gbk': ['terpene'],
#   'contig_00011.region001.gbk': ['T2PKS', 'melanin', 'NRPS-like', 'NRPS'],
#   'contig_00012.region001.gbk': ['NRPS-like'],
#   'contig_00025.region001.gbk': ['NRPS', 'NRPS-like'],
#   'contig_00026.region001.gbk': ['NRPS', 'NRPS-like', 'terpene'],
#   'contig_00027.region001.gbk': ['T3PKS'],
#   'contig_00028.region001.gbk': ['NRPS'],
#   'contig_00033.region001.gbk': ['terpene', 'NRPS'],
#   'contig_00034.region001.gbk': ['hglE-KS'],
#   'contig_00036.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00045.region001.gbk': ['T3PKS', 'phenazine', 'other'],
#   'contig_00053.region001.gbk': ['T2PKS'],
#   'contig_00057.region001.gbk': ['terpene'],
#   'contig_00059.region001.gbk': ['NRPS-like'],
#   'contig_00067.region001.gbk': ['NRPS-like'],
#   'contig_00074.region001.gbk': ['RiPP-like'],
#   'contig_00080.region001.gbk': ['T1PKS'],
#   'contig_00082.region001.gbk': ['NRPS-like'],
#   'contig_00097.region001.gbk': ['T1PKS'],
#   'contig_00102.region001.gbk': ['siderophore'],
#   'contig_00122.region001.gbk': ['T1PKS'],
#   'contig_00137.region001.gbk': ['NRPS'],
#   'contig_00139.region001.gbk': ['phosphonate'],
#   'contig_00142.region001.gbk': ['T1PKS', 'NRPS'],
#   'contig_00144.region001.gbk': ['T1PKS', 'NRPS-like'],
#   'contig_00152.region001.gbk': ['NRPS'],
#   'contig_00160.region001.gbk': ['T3PKS'],
#   'contig_00161.region001.gbk': ['T1PKS'],
#   'contig_00168.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00176.region001.gbk': ['NRPS'],
#   'contig_00187.region001.gbk': ['T1PKS'],
#   'contig_00193.region001.gbk': ['terpene'],
#   'contig_00205.region001.gbk': ['T1PKS'],
#   'contig_00210.region001.gbk': ['NRPS'],
#   'contig_00233.region001.gbk': ['terpene'],
#   'contig_00275.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00279.region001.gbk': ['T1PKS'],
#   'contig_00285.region001.gbk': ['NRPS'],
#   'contig_00301.region001.gbk': ['lanthipeptide-class-iv'],
#   'contig_00312.region001.gbk': ['siderophore'],
#   'contig_00326.region001.gbk': ['lanthipeptide-class-iv'],
#   'contig_00340.region001.gbk': ['lassopeptide'],
#   'contig_00375.region001.gbk': ['butyrolactone'],
#   'contig_00380.region001.gbk': ['T1PKS'],
#   'contig_00391.region001.gbk': ['RiPP-like'],
#   'contig_00410.region001.gbk': ['NRPS-like', 'T1PKS'],
#   'contig_00459.region001.gbk': ['redox-cofactor'],
#   'contig_00481.region001.gbk': ['NRPS-like'],
#   'contig_00586.region001.gbk': ['RiPP-like'],
#   'contig_00594.region001.gbk': ['terpene'],
#   'contig_00596.region001.gbk': ['terpene'],
#   'contig_00610.region001.gbk': ['NAPAA'],
#   'contig_00616.region001.gbk': ['T1PKS'],
#   'contig_00617.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00628.region001.gbk': ['T1PKS'],
#   'contig_00688.region001.gbk': ['other'],
#   'contig_00695.region001.gbk': ['NRPS'],
#   'contig_00730.region001.gbk': ['siderophore'],
#   'contig_00744.region001.gbk': ['NRPS-like']},
#  'MBT7': {'contig_00002.region001.gbk': ['NRPS'],
#   'contig_00005.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00007.region001.gbk': ['NRPS', 'T2PKS'],
#   'contig_00016.region001.gbk': ['NRPS'],
#   'contig_00017.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00021.region001.gbk': ['terpene'],
#   'contig_00022.region001.gbk': ['T1PKS'],
#   'contig_00027.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00028.region001.gbk': ['terpene'],
#   'contig_00029.region001.gbk': ['NRPS-like', 'NAPAA'],
#   'contig_00047.region001.gbk': ['NRPS'],
#   'contig_00048.region001.gbk': ['siderophore'],
#   'contig_00051.region001.gbk': ['lanthipeptide-class-iv'],
#   'contig_00064.region001.gbk': ['siderophore'],
#   'contig_00076.region001.gbk': ['linaridin'],
#   'contig_00077.region001.gbk': ['NRPS'],
#   'contig_00093.region001.gbk': ['T1PKS'],
#   'contig_00101.region001.gbk': ['RiPP-like'],
#   'contig_00127.region001.gbk': ['other'],
#   'contig_00128.region001.gbk': ['terpene'],
#   'contig_00134.region001.gbk': ['terpene'],
#   'contig_00150.region001.gbk': ['butyrolactone'],
#   'contig_00159.region001.gbk': ['melanin'],
#   'contig_00181.region001.gbk': ['butyrolactone'],
#   'contig_00182.region001.gbk': ['NRPS'],
#   'contig_00189.region001.gbk': ['CDPS'],
#   'contig_00210.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00216.region001.gbk': ['NAPAA'],
#   'contig_00220.region001.gbk': ['RRE-containing'],
#   'contig_00245.region001.gbk': ['T1PKS'],
#   'contig_00266.region001.gbk': ['thiopeptide', 'LAP'],
#   'contig_00272.region001.gbk': ['terpene'],
#   'contig_00279.region001.gbk': ['terpene'],
#   'contig_00312.region001.gbk': ['melanin'],
#   'contig_00372.region001.gbk': ['T1PKS'],
#   'contig_00376.region001.gbk': ['RRE-containing'],
#   'contig_00391.region001.gbk': ['siderophore'],
#   'contig_00393.region001.gbk': ['NRPS-like'],
#   'contig_00397.region001.gbk': ['CDPS'],
#   'contig_00424.region001.gbk': ['RiPP-like'],
#   'contig_00434.region001.gbk': ['NRPS'],
#   'contig_00454.region001.gbk': ['NRPS'],
#   'contig_00490.region001.gbk': ['ectoine'],
#   'contig_00498.region001.gbk': ['T2PKS']},
#  'MBT74': {'contig_00001.region001.gbk': ['T2PKS'],
#   'contig_00005.region001.gbk': ['phenazine'],
#   'contig_00018.region001.gbk': ['melanin'],
#   'contig_00019.region001.gbk': ['NAPAA'],
#   'contig_00025.region001.gbk': ['siderophore'],
#   'contig_00029.region001.gbk': ['NRPS'],
#   'contig_00030.region001.gbk': ['terpene'],
#   'contig_00038.region001.gbk': ['T3PKS'],
#   'contig_00039.region001.gbk': ['NRPS-like', 'T1PKS', 'NRPS'],
#   'contig_00042.region001.gbk': ['ectoine'],
#   'contig_00046.region001.gbk': ['RiPP-like'],
#   'contig_00050.region001.gbk': ['terpene'],
#   'contig_00067.region001.gbk': ['siderophore'],
#   'contig_00068.region001.gbk': ['T1PKS'],
#   'contig_00077.region001.gbk': ['thiopeptide', 'LAP'],
#   'contig_00091.region001.gbk': ['T3PKS'],
#   'contig_00094.region001.gbk': ['RiPP-like'],
#   'contig_00108.region001.gbk': ['siderophore'],
#   'contig_00150.region001.gbk': ['terpene'],
#   'contig_00175.region001.gbk': ['butyrolactone']},
#  'MBT77': {'contig_00002.region001.gbk': ['NRPS-like', 'NRPS'],
#   'contig_00009.region001.gbk': ['siderophore'],
#   'contig_00014.region001.gbk': ['terpene'],
#   'contig_00029.region001.gbk': ['melanin'],
#   'contig_00030.region001.gbk': ['betalactone'],
#   'contig_00032.region001.gbk': ['ectoine'],
#   'contig_00042.region001.gbk': ['T3PKS'],
#   'contig_00045.region001.gbk': ['other'],
#   'contig_00047.region001.gbk': ['terpene'],
#   'contig_00065.region001.gbk': ['NRPS'],
#   'contig_00069.region001.gbk': ['siderophore'],
#   'contig_00077.region001.gbk': ['NRPS', 'blactam', 'NRPS-like'],
#   'contig_00081.region001.gbk': ['terpene'],
#   'contig_00087.region001.gbk': ['lassopeptide'],
#   'contig_00102.region001.gbk': ['terpene'],
#   'contig_00109.region001.gbk': ['RiPP-like'],
#   'contig_00110.region001.gbk': ['other', 'T1PKS'],
#   'contig_00116.region001.gbk': ['redox-cofactor'],
#   'contig_00133.region001.gbk': ['melanin'],
#   'contig_00162.region001.gbk': ['NRPS', 'T1PKS'],
#   'contig_00173.region001.gbk': ['arylpolyene', 'ladderane'],
#   'contig_00176.region001.gbk': ['T3PKS'],
#   'contig_00179.region001.gbk': ['NRPS'],
#   'contig_00193.region001.gbk': ['T1PKS'],
#   'contig_00200.region001.gbk': ['butyrolactone'],
#   'contig_00201.region001.gbk': ['terpene'],
#   'contig_00206.region001.gbk': ['lanthipeptide-class-ii', 'NRPS'],
#   'contig_00222.region001.gbk': ['NRPS'],
#   'contig_00230.region001.gbk': ['siderophore'],
#   'contig_00245.region001.gbk': ['other'],
#   'contig_00262.region001.gbk': ['butyrolactone'],
#   'contig_00263.region001.gbk': ['lassopeptide'],
#   'contig_00274.region001.gbk': ['butyrolactone'],
#   'contig_00288.region001.gbk': ['NRPS'],
#   'contig_00306.region001.gbk': ['other'],
#   'contig_00327.region001.gbk': ['NRPS'],
#   'contig_00336.region001.gbk': ['RiPP-like'],
#   'contig_00349.region001.gbk': ['NRPS-like'],
#   'contig_00365.region001.gbk': ['NRPS-like'],
#   'contig_00374.region001.gbk': ['NRPS-like']},
#  'MBT82': {'contig_00002.region001.gbk': ['terpene'],
#   'contig_00004.region001.gbk': ['NRPS'],
#   'contig_00006.region001.gbk': ['T1PKS', 'NRPS'],
#   'contig_00009.region001.gbk': ['NRPS', 'T2PKS'],
#   'contig_00012.region001.gbk': ['terpene'],
#   'contig_00022.region001.gbk': ['NRPS-like', 'other', 'arylpolyene'],
#   'contig_00038.region001.gbk': ['terpene'],
#   'contig_00049.region001.gbk': ['T1PKS', 'butyrolactone'],
#   'contig_00052.region001.gbk': ['linaridin'],
#   'contig_00068.region001.gbk': ['T3PKS'],
#   'contig_00071.region001.gbk': ['NRPS'],
#   'contig_00072.region001.gbk': ['melanin'],
#   'contig_00086.region001.gbk': ['other'],
#   'contig_00090.region001.gbk': ['lanthipeptide-class-iv'],
#   'contig_00111.region001.gbk': ['terpene'],
#   'contig_00112.region001.gbk': ['RiPP-like'],
#   'contig_00117.region001.gbk': ['terpene'],
#   'contig_00119.region001.gbk': ['butyrolactone'],
#   'contig_00120.region001.gbk': ['NAPAA'],
#   'contig_00122.region001.gbk': ['T1PKS'],
#   'contig_00130.region001.gbk': ['lanthipeptide-class-iii'],
#   'contig_00140.region001.gbk': ['melanin'],
#   'contig_00153.region001.gbk': ['NRPS'],
#   'contig_00155.region001.gbk': ['LAP', 'thiopeptide'],
#   'contig_00172.region001.gbk': ['siderophore'],
#   'contig_00176.region001.gbk': ['NRPS'],
#   'contig_00200.region001.gbk': ['butyrolactone'],
#   'contig_00206.region001.gbk': ['terpene'],
#   'contig_00225.region001.gbk': ['CDPS'],
#   'contig_00230.region001.gbk': ['terpene'],
#   'contig_00253.region001.gbk': ['cyanobactin'],
#   'contig_00273.region001.gbk': ['siderophore'],
#   'contig_00278.region001.gbk': ['NRPS'],
#   'contig_00314.region001.gbk': ['RiPP-like'],
#   'contig_00332.region001.gbk': ['lanthipeptide-class-ii'],
#   'contig_00334.region001.gbk': ['NRPS'],
#   'contig_00343.region001.gbk': ['CDPS'],
#   'contig_00439.region001.gbk': ['NRPS']},
#  'MBT90': {'contig_00001.region001.gbk': ['redox-cofactor'],
#   'contig_00002.region001.gbk': ['NRPS'],
#   'contig_00002.region002.gbk': ['NRPS-like', 'NRPS'],
#   'contig_00009.region001.gbk': ['RiPP-like'],
#   'contig_00009.region002.gbk': ['T1PKS', 'butyrolactone', 'other'],
#   'contig_00010.region001.gbk': ['ectoine'],
#   'contig_00026.region001.gbk': ['terpene'],
#   'contig_00029.region001.gbk': ['T3PKS'],
#   'contig_00035.region001.gbk': ['betalactone'],
#   'contig_00036.region001.gbk': ['terpene'],
#   'contig_00039.region001.gbk': ['other'],
#   'contig_00039.region002.gbk': ['lassopeptide'],
#   'contig_00044.region001.gbk': ['melanin'],
#   'contig_00046.region001.gbk': ['siderophore'],
#   'contig_00056.region001.gbk': ['siderophore'],
#   'contig_00057.region001.gbk': ['ladderane', 'arylpolyene'],
#   'contig_00064.region001.gbk': ['melanin'],
#   'contig_00066.region001.gbk': ['NRPS'],
#   'contig_00068.region001.gbk': ['terpene'],
#   'contig_00081.region001.gbk': ['T1PKS', 'NRPS'],
#   'contig_00087.region001.gbk': ['RiPP-like'],
#   'contig_00097.region001.gbk': ['NRPS', 'NRPS-like'],
#   'contig_00099.region001.gbk': ['terpene'],
#   'contig_00119.region001.gbk': ['siderophore'],
#   'contig_00138.region001.gbk': ['T3PKS'],
#   'contig_00144.region001.gbk': ['lassopeptide'],
#   'contig_00146.region001.gbk': ['NRPS', 'lanthipeptide-class-ii'],
#   'contig_00158.region001.gbk': ['terpene'],
#   'contig_00191.region001.gbk': ['butyrolactone'],
#   'contig_00198.region001.gbk': ['thioamitides'],
#   'contig_00217.region001.gbk': ['other'],
#   'contig_00235.region001.gbk': ['other'],
#   'contig_00245.region001.gbk': ['NRPS'],
#   'contig_00265.region001.gbk': ['NRPS-like'],
#   'contig_00279.region001.gbk': ['butyrolactone']},
#  'Streptomyces-scopuliridis': {'NZ_JOEI01000001.region001.gbk': ['NRPS',
#    'NRPS-like',
#    'ladderane',
#    'arylpolyene',
#    'T2PKS'],
#   'NZ_JOEI01000001.region002.gbk': ['terpene'],
#   'NZ_JOEI01000002.region001.gbk': ['NRPS', 'prodigiosin'],
#   'NZ_JOEI01000002.region002.gbk': ['T1PKS', 'NRPS'],
#   'NZ_JOEI01000002.region003.gbk': ['NAPAA'],
#   'NZ_JOEI01000003.region001.gbk': ['terpene'],
#   'NZ_JOEI01000004.region001.gbk': ['siderophore'],
#   'NZ_JOEI01000004.region002.gbk': ['butyrolactone'],
#   'NZ_JOEI01000005.region001.gbk': ['terpene'],
#   'NZ_JOEI01000005.region002.gbk': ['RRE-containing'],
#   'NZ_JOEI01000005.region003.gbk': ['terpene'],
#   'NZ_JOEI01000005.region004.gbk': ['RiPP-like'],
#   'NZ_JOEI01000006.region001.gbk': ['linaridin'],
#   'NZ_JOEI01000006.region002.gbk': ['siderophore'],
#   'NZ_JOEI01000010.region001.gbk': ['butyrolactone'],
#   'NZ_JOEI01000010.region002.gbk': ['T1PKS'],
#   'NZ_JOEI01000011.region001.gbk': ['T3PKS'],
#   'NZ_JOEI01000015.region001.gbk': ['NRPS-like'],
#   'NZ_JOEI01000015.region002.gbk': ['RRE-containing'],
#   'NZ_JOEI01000017.region001.gbk': ['NRPS', 'T1PKS'],
#   'NZ_JOEI01000018.region001.gbk': ['ectoine'],
#   'NZ_JOEI01000019.region001.gbk': ['T1PKS', 'hglE-KS'],
#   'NZ_JOEI01000022.region001.gbk': ['ladderane', 'arylpolyene', 'NRPS'],
#   'NZ_JOEI01000023.region001.gbk': ['melanin', 'T3PKS'],
#   'NZ_JOEI01000029.region001.gbk': ['lanthipeptide-class-v', 'LAP'],
#   'NZ_JOEI01000031.region001.gbk': ['siderophore'],
#   'NZ_JOEI01000032.region001.gbk': ['terpene'],
#   'NZ_JOEI01000034.region001.gbk': ['NRPS'],
#   'NZ_JOEI01000034.region002.gbk': ['nucleoside'],
#   'NZ_JOEI01000037.region001.gbk': ['T1PKS', 'NRPS-like'],
#   'NZ_JOEI01000039.region001.gbk': ['T1PKS'],
#   'NZ_JOEI01000042.region001.gbk': ['NRPS'],
#   'NZ_JOEI01000043.region001.gbk': ['T1PKS'],
#   'NZ_JOEI01000044.region001.gbk': ['ectoine'],
#   'NZ_JOEI01000052.region001.gbk': ['NRPS'],
#   'NZ_JOEI01000053.region001.gbk': ['NRPS'],
#   'NZ_JOEI01000055.region001.gbk': ['NRPS'],
#   'NZ_JOEI01000059.region001.gbk': ['NRPS'],
#   'NZ_JOEI01000060.region001.gbk': ['NRPS'],
#   'NZ_JOEI01000063.region001.gbk': ['NRPS']}}

# %%
dict_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7252/3743155698.py in <module>
# ----> 1 dict_data
#
# NameError: name 'dict_data' is not defined

# %%
stop

# %% [markdown]
# ### Extract most similar known cluster for T2PKS clusters

# %%
# get path to file
cwd = os.getcwd()
folder = cwd + '/Hm77.contig-sequences-gapclosed/knownclusterblast'
filename = 'contig_00002_c1.txt'
filepath = folder + '/' + filename

# %%
# open file as list

count = 0

with open(filepath, 'r') as f:
    knownclusterblast = f.readlines()

# %%
# extract best known hit
start = knownclusterblast.index('Details:\n')
hit_bgc_num = ""
hit_bgc_name = ""
hit_bgc_type = ""

for line in range(start, start + 10):
    if knownclusterblast[line].startswith('1.'):
        hit_bgc_num = knownclusterblast[line][3:].strip()
    if knownclusterblast[line].startswith('Source'):
        hit_bgc_name = knownclusterblast[line][8:].strip()
    if knownclusterblast[line].startswith('Type'):
        hit_bgc_type = knownclusterblast[line][6:].strip()
        break

dict_hits = dict()

dict_hits[filename] = [hit_bgc_num, hit_bgc_name, hit_bgc_type]

# %%
print(dict_hits)

# %%
print(hit_bgc_num[0:])

# %%
knownclusterblast
